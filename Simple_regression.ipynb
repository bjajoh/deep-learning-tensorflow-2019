# %% [markdown]
# # Deep learning programming I-A: Regression
# Felix Wiewel, Institute of Signal Processing and System Theory, University of Stuttgart, 23.05.2019
#
# ## Introduction
# This programming exercise is the first of a series of exercises, which are intended as a supplement to the theoretical part of the Deep Learning course offered by the ISS. The goal is to introduce you to basic tasks and applications of methods you have encountered in the lecture. After completing the exercise you should be familiar with the basic ideas and one, possibly simple, way of solving the respective task. It is worth mentioning that most of the tasks can be solved in many different, not necessarily deep learning based, ways and the solution presented here is just one of them.
#
# ## Regression
#
# In this exercise we consider the problem of regression, where we are interested in modeling a functional dependence between different variables with, possibly noisy, observations of input-output pairs. Mathematically such a dependence can be formulated as
#
# $\mathbf{y}=f(\mathbf{x})+\boldsymbol{\epsilon}$,
#
# where $\mathbf{y}\in\mathbb{R}^{M}$ and $\mathbf{x}\in\mathbb{R}^{N}$ are the input and output observations, $f:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ is the function mapping inputs to outputs and $\boldsymbol{\epsilon}\in\mathbb{R}^{M}$ is a random vector, which models noise in our observations. Note that this assumes additive noise that only acts on the output and not on the input variable, which might not be true in all practical applications but is a reasonable approximation. For regression we are now interested in estimating the functional relationship $f$ between the inputs and outputs. This can be done in many different ways, not just with neural networks, but for this exercise we focus on approximating this relationship with a neural network $g_{\boldsymbol{\theta}}:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ with parameter vector $\boldsymbol{\theta}$. The task is now to choose the parameters of the neural network in a way that results in a "good" approximation of $f$ with $g_{\boldsymbol{\theta}}$.
#
# In order to quantify how "good" our neural network can approximate $f$, we adopt a probabilistic view. For this we make the assumption that the noise $\boldsymbol{\epsilon}$ is a random vector drawn from a known dustribution, which enables us to derive a suitable cost function for training our neural network and also for quantifying a "good" approximation.
#
# ### Mathematical formulation
# If we assume that the noise $\boldsymbol{\epsilon}$ is drawn from a gaussian distribution, e.g. $\boldsymbol{\epsilon}\sim\mathcal{N}(\mathbf{0},\sigma^{2}\mathbf{I})$, we can use
#
# $\mathbf{y}=g_{\boldsymbol{\theta}}(\mathbf{x})+\boldsymbol{\epsilon}\Rightarrow \mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})=\boldsymbol{\epsilon}$
#
# to derive a log likelihood. Since the probability density function (pdf) of a multivariate normal distribution is given by
#
# $p(\mathbf{x})=\dfrac{1}{\sqrt{(2\pi)^{D}\vert\mathbf{C}\vert}}\mathrm{e}^{-\dfrac{1}{2}(\mathbf{x}-\boldsymbol{\mu})\mathbf{C}^{-1}(\mathbf{x}-\boldsymbol{\mu})^{T}}$,
#
# we get
#
# $\ln{p(\boldsymbol{\epsilon})}=\ln{\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}}}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$.
#
# Replacing $\boldsymbol{\epsilon}$ by $\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})$ yields the log likelihood for one particular input-output pair:
#
# $\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})=\ln {p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$
#
# This log likelihood measures how likely the input-output pair is and we can use it to train our neural network. For this we maximize the expected log likelihood over all input-output pairs under the assumption that the noise is idependent and identically distributed (i.i.d.) over all input-output pairs. This corresponds to finding the parameters $\boldsymbol{\theta}^{\star}$ of our neural network, which maximize the the expected probability for observing the corresponding input-output pairs. Mathematically the optimal parameters for our neural network are given by
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[-\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}\right]\approx\arg\min_{\boldsymbol{\theta}}\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where all terms, which are independent of $\boldsymbol{\theta}$, are ignored and the expectation operator is approximated by the mean over all $N_{D}$ input-output pairs. In other words we are maximizing the log likelihood by minimizing the mean squared error loss over all input-output pairs in our dataset, hence this approach is called Maximum Likelihood (ML) estimation. For solving this optimization problem and obtaining the optimal network parameters, stochastic gradient descent (SGD) or one of it's many variants is typically used.
#
# It is worth noting, that choosing different distributions for the noise $\boldsymbol{\epsilon}$ leads to different log likelihoods and therefore different cost functions for training the neural network. Another commonly used distribution for modelling the noise in regression tasks is the laplace distribution. Deriving the log likelihood and the corresponding costfunction leads to the mean absolute error, which is given by the $l_{1}$-norm of the difference between observations predictions of the neural network. This cost function is considered more robust against outliers since these have less influence on the averall loss compared to the mean squared error.
#
# ###  Implementation
#
# In the following we consider a simple regression task, implement a neural network and train it based on the mathematical fomrulation above. For this we first need to create a set of input-output pairs, which then needs to be partitioned into a training, validation and test set. We also define some constants to be used for partitioning the data and the hyperparameters for our neural network.
#
# But before we can start, we need to install tensorflow and import the necessary packages tensorflow, numpy and matplotlib.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Next we define our constants and set the random seeds of tensorflow and numpy in order to get reproducable results.

# %%
N_train_samples = 600
N_validation_samples = 100
N_test_samples = 100
N_samples = N_train_samples + N_validation_samples + N_test_samples
noise_sig = 0.1
N_epochs = 150
batch_size = 8
learning_rate = 0.01

tf.random.set_seed(0)
np.random.seed(0)

# %% [markdown]
# We create $600$ training samples, $100$ validation samples to optimize our hyperparameters and $100$ test samples, which are used to check if our model can generalize to unseen data. Furthermore we set the level of noise added to the observations. For training the model we plan to train it for $150$ epochs with a batch size of $8$ and a learning rate of $0.81$. Next we create the actual signal and plot it.

# %%
x = np.linspace(0.0, 3.0, N_samples, dtype=np.float32)
y = np.expand_dims(np.sin(1.0+x*x) + noise_sig*np.random.randn(N_samples).astype(np.float32), axis=-1)
y_true = np.sin(1.0+x*x)

plt.plot(x, y)
plt.plot(x, y_true)
plt.legend(["Observation", "Ground truth"])
plt.show()

# %% [markdown]
# With the input-output pairs created, your first task is now to partition the data in the training, validation and test sets. Keep in mind that we have created the data in a structured way, i.e. the input-output pairs are ordered. This means you need to shuffle the data before partitioning it.

# %%
shuffle_idx = np.arange(0, N_samples)
np.random.shuffle(shuffle_idx)
x_shuffled = x[shuffle_idx]
y_shuffled = y[shuffle_idx]
x_train = x_shuffled[0:N_train_samples]
y_train = y_shuffled[0:N_train_samples]
x_validation = x_shuffled[N_train_samples:N_train_samples+N_validation_samples]
y_validation = y_shuffled[N_train_samples:N_train_samples+N_validation_samples]
x_test = x_shuffled[N_train_samples+N_validation_samples:]
y_test = y_shuffled[N_train_samples+N_validation_samples:]

# %% [markdown]
# In order to feed the data to our model, we will use the Dataset class provided by tensorflow. This class is simple to use and provides all the functionality we need for shuffling, batching and feeding the data to our model. It is also tightly integrated into the tensorflow framework, which makes it very performant. Performance is not an aspect we need to worry about in this exercise, but it is important in more demanding applications.
#
# In this exercise we instantiate a separate Dataset object for the training, validation and test data sets, where we shuffle and repeat just the training data set. Shuffling the validation and test data sets is not necessary, since we only evaluate the loss on those data sets and do not perform SGD on it. Please fill in the missing part of the code.

# %%
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(N_train_samples).batch(batch_size).repeat()
validation_ds = tf.data.Dataset.from_tensor_slices((x_validation, y_validation))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# In this exercise we will create a a simple neural network with two hidden layers containing $10$ neurons. For creating a model and keeping track of its weights a class called MyModel is used. When initializing an instance of this class the necessary variables are created and stored in a list called "trainable_variables". This makes it easy to get all trainable variables of the model. We also override the \__call__ method of this class in order to implement the forward pass of the neural network. This method should accept the inputs to the neural network and should return the result of the forward pass as an output. Please fill in the missing part of the code and select suitable activation functions for the different layers.

# %%
class MyModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.normal([1, 10]), name="W0")
        self.b0 = tf.Variable(tf.zeros(10), name="b0")
        self.W1 = tf.Variable(tf.random.normal([10, 10]), name="W1")
        self.b1 = tf.Variable(tf.zeros(10), name="b1")
        self.W2 = tf.Variable(tf.random.normal([10, 1]), name="W2")
        self.b2 = tf.Variable(tf.zeros(1), name="b2")
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W0), self.b0))
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W1), self.b1))
        output = tf.add(tf.matmul(output, self.W2), self.b2)
        return output

# %% [markdown]
# Now after the model class is defined we can instantiate a MyModel object by running

# %%
mdl = MyModel()

# %% [markdown]
# We can now use the model to make predictions by calling it. In the following we predict on the inputs an plot the result.

# %%
y_pred = mdl(x)
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Since we have initialized the variables of the neural network randomly, it's prediction is also random. In order to fit the model we need to minimize the expected mean squared error over all input-ouput pairs in our training data set. For this we need to create a function, that performs a training step when provided with the model, an optimizer and a batch of input-ouput pairs.

# %%
def train_step(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model(x)
        loss_val = tf.reduce_mean(tf.square(y-y_pred))
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# This function uses the GradientTape to record the operations for which gradients have to be calculated. In our case this is the forward pass through our model and the computation of the loss function. After these operations are recoded we can get its gradients and apply these through the use of an optimizer. Finally we return the loss value in order to print it.
#
# With the training step function defined we now need to choose a suitable optimizer. Tensorflow offers a wide variety of optimizers but in this exercise we will use the Adam optimizer.

# %%
opt = tf.optimizers.RMSprop(learning_rate)

# %% [markdown]
# We now have everything we need to start training the model. For this we repeatedly sample a batch of input-output pairs from our training data set and use the train_step function to minimize the loss function over this batch. We repeat this until we have iterated over the complete training data set once. After this we compute the loss on the validation data set and print it.

# %%
epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_ds:
    train_loss += train_step(mdl, opt, x_t, y_t)
    train_iters += 1
    if (train_iters >= int(N_train_samples/batch_size)):
        for x_v, y_v in validation_ds:
            y_pred = mdl(x_v)
            validation_loss = tf.reduce_mean(tf.square(y_v-y_pred))
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 1.9916 Validation loss: 0.20077
# Epoch: 1 Train loss: 0.29506 Validation loss: 0.066572
# Epoch: 2 Train loss: 0.234 Validation loss: 0.077188
# Epoch: 3 Train loss: 0.21531 Validation loss: 0.029865
# Epoch: 4 Train loss: 0.18293 Validation loss: 0.0062291
# Epoch: 5 Train loss: 0.16924 Validation loss: 0.004077
# Epoch: 6 Train loss: 0.1524 Validation loss: 0.031568
# Epoch: 7 Train loss: 0.13582 Validation loss: 0.061455
# Epoch: 8 Train loss: 0.12127 Validation loss: 0.0072608
# Epoch: 9 Train loss: 0.10554 Validation loss: 0.005387
# Epoch: 10 Train loss: 0.10403 Validation loss: 0.017581
# Epoch: 11 Train loss: 0.096962 Validation loss: 0.02316
# Epoch: 12 Train loss: 0.089423 Validation loss: 0.062391
# Epoch: 13 Train loss: 0.090134 Validation loss: 0.036649
# Epoch: 14 Train loss: 0.084135 Validation loss: 0.022931
# Epoch: 15 Train loss: 0.081472 Validation loss: 0.025729
# Epoch: 16 Train loss: 0.081318 Validation loss: 0.051058
# Epoch: 17 Train loss: 0.078385 Validation loss: 0.029007
# Epoch: 18 Train loss: 0.075453 Validation loss: 0.010901
# Epoch: 19 Train loss: 0.070759 Validation loss: 0.031005
# Epoch: 20 Train loss: 0.067764 Validation loss: 0.019102
# Epoch: 21 Train loss: 0.061847 Validation loss: 0.013145
# Epoch: 22 Train loss: 0.054384 Validation loss: 0.0013717
# Epoch: 23 Train loss: 0.052669 Validation loss: 0.028092
# Epoch: 24 Train loss: 0.046937 Validation loss: 0.012111
# Epoch: 25 Train loss: 0.045791 Validation loss: 0.0067406
# Epoch: 26 Train loss: 0.047865 Validation loss: 0.034627
# Epoch: 27 Train loss: 0.047273 Validation loss: 0.017896
# Epoch: 28 Train loss: 0.039777 Validation loss: 0.026316
# Epoch: 29 Train loss: 0.041974 Validation loss: 0.0073053
# Epoch: 30 Train loss: 0.043534 Validation loss: 0.019914
# Epoch: 31 Train loss: 0.038924 Validation loss: 0.034338
# Epoch: 32 Train loss: 0.038693 Validation loss: 0.0020333
# Epoch: 33 Train loss: 0.037511 Validation loss: 0.0053235
# Epoch: 34 Train loss: 0.037396 Validation loss: 0.028232
# Epoch: 35 Train loss: 0.038853 Validation loss: 0.025911
# Epoch: 36 Train loss: 0.03604 Validation loss: 0.018725
# Epoch: 37 Train loss: 0.033635 Validation loss: 0.11596
# Epoch: 38 Train loss: 0.037896 Validation loss: 9.6417e-05
# Epoch: 39 Train loss: 0.037177 Validation loss: 0.00075587
# Epoch: 40 Train loss: 0.035449 Validation loss: 0.014153
# Epoch: 41 Train loss: 0.035418 Validation loss: 0.0064984
# Epoch: 42 Train loss: 0.034868 Validation loss: 0.044342
# Epoch: 43 Train loss: 0.033317 Validation loss: 0.00050435
# Epoch: 44 Train loss: 0.035719 Validation loss: 0.02702
# Epoch: 45 Train loss: 0.036218 Validation loss: 0.023435
# Epoch: 46 Train loss: 0.032483 Validation loss: 0.02695
# Epoch: 47 Train loss: 0.034855 Validation loss: 0.0038148
# Epoch: 48 Train loss: 0.033314 Validation loss: 0.00030571
# Epoch: 49 Train loss: 0.034447 Validation loss: 0.0046665
# Epoch: 50 Train loss: 0.033442 Validation loss: 0.0006873
# Epoch: 51 Train loss: 0.031069 Validation loss: 0.048529
# Epoch: 52 Train loss: 0.030405 Validation loss: 0.0032675
# Epoch: 53 Train loss: 0.032387 Validation loss: 0.012551
# Epoch: 54 Train loss: 0.030282 Validation loss: 0.03356
# Epoch: 55 Train loss: 0.032603 Validation loss: 0.004128
# Epoch: 56 Train loss: 0.029249 Validation loss: 0.0019234
# Epoch: 57 Train loss: 0.031915 Validation loss: 0.036421
# Epoch: 58 Train loss: 0.030661 Validation loss: 0.011116
# Epoch: 59 Train loss: 0.029889 Validation loss: 0.015301
# Epoch: 60 Train loss: 0.027068 Validation loss: 0.018742
# Epoch: 61 Train loss: 0.03081 Validation loss: 0.0048591
# Epoch: 62 Train loss: 0.030427 Validation loss: 0.027647
# Epoch: 63 Train loss: 0.028961 Validation loss: 0.0039725
# Epoch: 64 Train loss: 0.028986 Validation loss: 0.019016
# Epoch: 65 Train loss: 0.035687 Validation loss: 0.0057921
# Epoch: 66 Train loss: 0.028266 Validation loss: 0.023206
# Epoch: 67 Train loss: 0.029149 Validation loss: 0.0026538
# Epoch: 68 Train loss: 0.029363 Validation loss: 6.4047e-05
# Epoch: 69 Train loss: 0.028603 Validation loss: 0.025149
# Epoch: 70 Train loss: 0.031692 Validation loss: 0.0015978
# Epoch: 71 Train loss: 0.029288 Validation loss: 0.022726
# Epoch: 72 Train loss: 0.029712 Validation loss: 0.0069975
# Epoch: 73 Train loss: 0.02804 Validation loss: 0.029477
# Epoch: 74 Train loss: 0.030252 Validation loss: 0.053979
# Epoch: 75 Train loss: 0.030464 Validation loss: 0.033782
# Epoch: 76 Train loss: 0.028756 Validation loss: 0.01427
# Epoch: 77 Train loss: 0.028525 Validation loss: 0.00044899
# Epoch: 78 Train loss: 0.027722 Validation loss: 0.029101
# Epoch: 79 Train loss: 0.027976 Validation loss: 0.0087322
# Epoch: 80 Train loss: 0.028345 Validation loss: 0.0045872
# Epoch: 81 Train loss: 0.027842 Validation loss: 0.015106
# Epoch: 82 Train loss: 0.026082 Validation loss: 0.0026947
# Epoch: 83 Train loss: 0.027916 Validation loss: 0.00026711
# Epoch: 84 Train loss: 0.027259 Validation loss: 0.0065966
# Epoch: 85 Train loss: 0.029878 Validation loss: 0.0071314
# Epoch: 86 Train loss: 0.033303 Validation loss: 0.015523
# Epoch: 87 Train loss: 0.023679 Validation loss: 0.020092
# Epoch: 88 Train loss: 0.025821 Validation loss: 0.0017541
# Epoch: 89 Train loss: 0.026955 Validation loss: 0.0013127
# Epoch: 90 Train loss: 0.029461 Validation loss: 0.0096529
# Epoch: 91 Train loss: 0.025273 Validation loss: 0.0023329
# Epoch: 92 Train loss: 0.02884 Validation loss: 0.0016105
# Epoch: 93 Train loss: 0.028713 Validation loss: 0.0030536
# Epoch: 94 Train loss: 0.023929 Validation loss: 0.0075244
# Epoch: 95 Train loss: 0.027567 Validation loss: 0.021033
# Epoch: 96 Train loss: 0.026152 Validation loss: 0.0011341
# Epoch: 97 Train loss: 0.029202 Validation loss: 0.00046123
# Epoch: 98 Train loss: 0.02747 Validation loss: 0.012389
# Epoch: 99 Train loss: 0.027039 Validation loss: 0.019094
# Epoch: 100 Train loss: 0.025061 Validation loss: 0.0021711
# Epoch: 101 Train loss: 0.026453 Validation loss: 0.015901
# Epoch: 102 Train loss: 0.030374 Validation loss: 0.015511
# Epoch: 103 Train loss: 0.023291 Validation loss: 0.00050292
# Epoch: 104 Train loss: 0.026503 Validation loss: 0.022481
# Epoch: 105 Train loss: 0.024453 Validation loss: 0.016275
# Epoch: 106 Train loss: 0.024926 Validation loss: 0.0029985
# Epoch: 107 Train loss: 0.025002 Validation loss: 0.033969
# Epoch: 108 Train loss: 0.026279 Validation loss: 0.003023
# Epoch: 109 Train loss: 0.024887 Validation loss: 0.0031442
# Epoch: 110 Train loss: 0.024762 Validation loss: 0.0029894
# Epoch: 111 Train loss: 0.026708 Validation loss: 0.0010851
# Epoch: 112 Train loss: 0.027898 Validation loss: 2.7344e-06
# Epoch: 113 Train loss: 0.023212 Validation loss: 0.017478
# Epoch: 114 Train loss: 0.023752 Validation loss: 0.0065667
# Epoch: 115 Train loss: 0.024997 Validation loss: 0.0047159
# Epoch: 116 Train loss: 0.023576 Validation loss: 0.019592
# Epoch: 117 Train loss: 0.024472 Validation loss: 0.034544
# Epoch: 118 Train loss: 0.02504 Validation loss: 0.0064161
# Epoch: 119 Train loss: 0.025013 Validation loss: 0.021135
# Epoch: 120 Train loss: 0.025411 Validation loss: 0.010891
# Epoch: 121 Train loss: 0.025803 Validation loss: 0.011193
# Epoch: 122 Train loss: 0.028073 Validation loss: 0.016387
# Epoch: 123 Train loss: 0.023822 Validation loss: 0.013188
# Epoch: 124 Train loss: 0.025067 Validation loss: 0.027642
# Epoch: 125 Train loss: 0.023701 Validation loss: 0.01393
# Epoch: 126 Train loss: 0.024071 Validation loss: 0.021394
# Epoch: 127 Train loss: 0.025294 Validation loss: 0.0021903
# Epoch: 128 Train loss: 0.023976 Validation loss: 0.01353
# Epoch: 129 Train loss: 0.024397 Validation loss: 0.0011689
# Epoch: 130 Train loss: 0.02543 Validation loss: 0.023059
# Epoch: 131 Train loss: 0.023677 Validation loss: 0.0098234
# Epoch: 132 Train loss: 0.027359 Validation loss: 0.013319
# Epoch: 133 Train loss: 0.023903 Validation loss: 0.0061123
# Epoch: 134 Train loss: 0.024292 Validation loss: 0.010185
# Epoch: 135 Train loss: 0.023119 Validation loss: 0.01763
# Epoch: 136 Train loss: 0.024197 Validation loss: 0.012557
# Epoch: 137 Train loss: 0.026154 Validation loss: 0.016176
# Epoch: 138 Train loss: 0.022167 Validation loss: 0.023412
# Epoch: 139 Train loss: 0.023463 Validation loss: 0.003116
# Epoch: 140 Train loss: 0.0234 Validation loss: 0.021264
# Epoch: 141 Train loss: 0.025064 Validation loss: 0.0088928
# Epoch: 142 Train loss: 0.024776 Validation loss: 0.012273
# Epoch: 143 Train loss: 0.022462 Validation loss: 0.013551
# Epoch: 144 Train loss: 0.024087 Validation loss: 0.022238
# Epoch: 145 Train loss: 0.022741 Validation loss: 0.00074881
# Epoch: 146 Train loss: 0.021951 Validation loss: 0.022997
# Epoch: 147 Train loss: 0.023621 Validation loss: 0.010749
# Epoch: 148 Train loss: 0.023609 Validation loss: 0.003605
# Epoch: 149 Train loss: 0.022678 Validation loss: 0.027493

# %% [markdown]
# After completion of the training process we use the test data set to test the models generalization to unseen data.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl(x_t)
    test_loss = tf.reduce_mean(tf.square(y_t-y_pred))
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 0.024435

# %% [markdown]
# After we have verified that our model achieves a similar loss on the test as on the validation and training data set, we can conclude that our model is not overfitting or underfitting and generalizes to unseen data. We can now predict on the inputs again and plot the results.

# %%
y_pred = mdl(x)
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Now our model has learned to approximate the function mapping from the input to the output. The capability of neural networks to learn from input-ouput pairs alone and approximate an arbitrary function, see universal approximation theorem, can be very useful if the mapping between the input and output is too complex to be captured with model based approaches. But learning from input-ouput pairs alone implies that the model will only be able to make accurate predictions over input ranges it has seen during training. In order to demonstrate this we will predict on an interval that exeeds the $\left[0,3\right]$ interval the model was trained on, i.e. we will predict on the interval $\left[-2,5\right]$.

# %%
x_generalize = np.linspace(-2.0, 5.0, N_samples, dtype=np.float32)
y_generalize = np.sin(1.0+x_generalize*x_generalize) + noise_sig*np.random.randn(N_samples).astype(np.float32)
y_truey_generalize = np.sin(1.0+x_generalize*x_generalize)
y_pred = mdl(x_generalize)
plt.plot(x_generalize, y_generalize)
plt.plot(x_generalize, y_truey_generalize)
plt.plot(x_generalize, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# As expected, the model is able to make farely accurate predictions on the interval it was trained on but makes unreliable predictions outside this interval.
#
# ### Regularization
# In this section we will explore the concept of regularization. As there is no theorem that can be used to determine the required size and structure of a neural network given a certain task, one has to find a suitable neural architecture by trial and error. This can result in choosing a architecture with a capacity that is higher than required for solving the given task and hence overfitting might occur. A common way to prevent large neural networks networks from overfitting is to employ some sort of regularization, e.g. weight norm penalty, dropout, early stopping and data augmentation. In this section we will focus on weight norm penalty as a regularization and derive a probabilistic interpretation for some of those.
#
# We start by restating the conditional probability of the output $\mathbf{y}$ given the input $\mathbf{x}$ and the networks parameters $\boldsymbol{\theta}$
#
# $p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})=\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}}$,
#
# which we used to derive the log likelihood. If we have some prior knowledge about the parameters of the neural network, which is given by a pdf $p(\boldsymbol{\theta})$ over the weights, we can use Bayes theorem to derive a posterior distribution
#
# $p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})=\dfrac{p(\boldsymbol{\theta},\mathbf{y}\vert\mathbf{x})}{p(\mathbf{y})}=\dfrac{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})p(\boldsymbol{\theta})}{p(\mathbf{y})}$
#
# where $p(\boldsymbol{\theta})$ is the  prior over the networks parameters. Similar to the derivation at the beginning of the exercise, we can use this posterior distribution to derive a cost function for training the neural network. In this case, however, we are not maximizing the log likelihood but the posterior distribution over the weights, hence this approach is called Maximum A Posteori (MAP) estimation of the parameters. Mathematically we can formulate this as
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\ln{p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})}\right]=\arg\max_{\boldsymbol{\theta}}\ln{p(\boldsymbol{\theta})}+\mathbb{E}\left[\ln{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}\right]$,
#
# where we used the fact that applying a strictly increasing function, e.g. $\ln{}$, does not change the position of the maximum of a cost function, ignored $p(\mathbf{y})$, since it is independent of the network parameters and dropped the expectation operator for $\ln{p(\boldsymbol{\theta})}$, since it is not depending on the random variable $\mathbf{x}$. Comparing the MAP estimate of the parameters with the ML estimate we derived above, shows that the only difference is the addition of $\ln{p(\boldsymbol{\theta})}$. This term is the regularization, i.e. the weight norm penalty. Depending on the distribution over $\boldsymbol{\theta}$ it can have different forms. If we choose a standard normal distribution, i.e. $\boldsymbol{\theta\sim\mathcal{N}(\mathbf{0},\mathbf{I})}$,  we get
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{2}^{2}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where we have made the same simplifications as for the ML estimation and also introduced the parameter $\lambda=\sigma^{2}$, which is used to control the strength of the regularization. This form of regularization is commonly known as $l_{2}$-norm or weight decay regularization. Choosing a prior where the weights follow an i.i.d laplacian distribution, i.e. $p(\boldsymbol{\theta})=\prod_{j}\dfrac{1}{2}\mathrm{e}^{\vert\theta_{j}\vert}$, leads to
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{1}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where the strength of the regularization is again controlled by $\lambda=\sigma^{2}$. this type of regularization is known as  $l_{1}$-norm and it has the property to induce sparsity in the parameters of the network.
#
# With this theoretical background on regularization we can now implement it and observe it's effects on the regression problem covered in this exercise. For this we will define a model with a high capacity and train it for a extended time to provoke overfitting. For this, we will increase the number of hidden neurons in both hidden layers to $100$ and $50$.

# %%
class MyBigModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.normal([1, 100]), name="W0")
        self.b0 = tf.Variable(tf.zeros(100), name="b0")
        self.W1 = tf.Variable(tf.random.normal([100, 50]), name="W1")
        self.b1 = tf.Variable(tf.zeros(50), name="b1")
        self.W2 = tf.Variable(tf.random.normal([50, 1]), name="W2")
        self.b2 = tf.Variable(tf.zeros(1), name="b2")
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W0), self.b0))
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W1), self.b1))
        output = tf.add(tf.matmul(output, self.W2), self.b2)
        return output

# %% [markdown]
# After creating one instance of this class we can again train it on our data set. We will also create a new optimizer for training this bigger model, since some optimizers adapt the learning rates for individual parameters during a training process and we do not want to train our bigger model with learning rates adopted from an earlier training run.

# %%
big_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

# %% [markdown]
# Now we are ready to train this bigger model using the same training step and training loop. In order to provoke overfitting we also reduce the number of samples in the training data set a lot, increase the batch size and train for a more epochs.

# %%
N_train_samples_overfit = 30
N_epochs = 1000
batch_size = 30

sel_idx = np.arange(0, N_train_samples)
sel_idx = np.random.choice(sel_idx, N_train_samples_overfit)
x_train_overfit = x_train[sel_idx]
y_train_overfit = y_train[sel_idx]

train_overfit_ds = tf.data.Dataset.from_tensor_slices((x_train_overfit, y_train_overfit)).shuffle(N_train_samples_overfit).batch(batch_size).repeat()

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    train_loss += train_step(big_mdl, big_opt, x_t, y_t)
    train_iters += 1
    if (train_iters >= int(N_train_samples/batch_size)):
        for x_v, y_v in validation_ds:
            y_pred = big_mdl(x_v)
            validation_loss = tf.reduce_mean(tf.square(y_v-y_pred))
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 3.775 Validation loss: 1.1466
# Epoch: 1 Train loss: 0.31587 Validation loss: 0.41025
# Epoch: 2 Train loss: 0.29375 Validation loss: 0.17775
# Epoch: 3 Train loss: 0.28277 Validation loss: 0.074253
# Epoch: 4 Train loss: 0.27405 Validation loss: 0.026254
# Epoch: 5 Train loss: 0.26578 Validation loss: 0.0054789
# Epoch: 6 Train loss: 0.25724 Validation loss: 9.3613e-06
# Epoch: 7 Train loss: 0.24811 Validation loss: 0.0062455
# Epoch: 8 Train loss: 0.23823 Validation loss: 0.026681
# Epoch: 9 Train loss: 0.22745 Validation loss: 0.070534
# Epoch: 10 Train loss: 0.21534 Validation loss: 0.15382
# Epoch: 11 Train loss: 0.20024 Validation loss: 0.27281
# Epoch: 12 Train loss: 0.18037 Validation loss: 0.31124
# Epoch: 13 Train loss: 0.16535 Validation loss: 0.25419
# Epoch: 14 Train loss: 0.15698 Validation loss: 0.20144
# Epoch: 15 Train loss: 0.14994 Validation loss: 0.16102
# Epoch: 16 Train loss: 0.14317 Validation loss: 0.12822
# Epoch: 17 Train loss: 0.13649 Validation loss: 0.10092
# Epoch: 18 Train loss: 0.12966 Validation loss: 0.079006
# Epoch: 19 Train loss: 0.12232 Validation loss: 0.063534
# Epoch: 20 Train loss: 0.11419 Validation loss: 0.054925
# Epoch: 21 Train loss: 0.10599 Validation loss: 0.051163
# Epoch: 22 Train loss: 0.099256 Validation loss: 0.050102
# Epoch: 23 Train loss: 0.094163 Validation loss: 0.05027
# Epoch: 24 Train loss: 0.090065 Validation loss: 0.050642
# Epoch: 25 Train loss: 0.086567 Validation loss: 0.050842
# Epoch: 26 Train loss: 0.083502 Validation loss: 0.050828
# Epoch: 27 Train loss: 0.080787 Validation loss: 0.05065
# Epoch: 28 Train loss: 0.078372 Validation loss: 0.050362
# Epoch: 29 Train loss: 0.076215 Validation loss: 0.050007
# Epoch: 30 Train loss: 0.074286 Validation loss: 0.049615
# Epoch: 31 Train loss: 0.072554 Validation loss: 0.049205
# Epoch: 32 Train loss: 0.070998 Validation loss: 0.048794
# Epoch: 33 Train loss: 0.069596 Validation loss: 0.04839
# Epoch: 34 Train loss: 0.068329 Validation loss: 0.048001
# Epoch: 35 Train loss: 0.067182 Validation loss: 0.047633
# Epoch: 36 Train loss: 0.066141 Validation loss: 0.047287
# Epoch: 37 Train loss: 0.065193 Validation loss: 0.046967
# Epoch: 38 Train loss: 0.064329 Validation loss: 0.046673
# Epoch: 39 Train loss: 0.063538 Validation loss: 0.046404
# Epoch: 40 Train loss: 0.062812 Validation loss: 0.046164
# Epoch: 41 Train loss: 0.062144 Validation loss: 0.045949
# Epoch: 42 Train loss: 0.061526 Validation loss: 0.04576
# Epoch: 43 Train loss: 0.060954 Validation loss: 0.045597
# Epoch: 44 Train loss: 0.060421 Validation loss: 0.04546
# Epoch: 45 Train loss: 0.059922 Validation loss: 0.045347
# Epoch: 46 Train loss: 0.059454 Validation loss: 0.04526
# Epoch: 47 Train loss: 0.05901 Validation loss: 0.045197
# Epoch: 48 Train loss: 0.058588 Validation loss: 0.045161
# Epoch: 49 Train loss: 0.058183 Validation loss: 0.045154
# Epoch: 50 Train loss: 0.057789 Validation loss: 0.04518
# Epoch: 51 Train loss: 0.0574 Validation loss: 0.045239
# Epoch: 52 Train loss: 0.057011 Validation loss: 0.045343
# Epoch: 53 Train loss: 0.05661 Validation loss: 0.045504
# Epoch: 54 Train loss: 0.056183 Validation loss: 0.045741
# Epoch: 55 Train loss: 0.055706 Validation loss: 0.046095
# Epoch: 56 Train loss: 0.055134 Validation loss: 0.046638
# Epoch: 57 Train loss: 0.054373 Validation loss: 0.04754
# Epoch: 58 Train loss: 0.053186 Validation loss: 0.049281
# Epoch: 59 Train loss: 0.050803 Validation loss: 0.053698
# Epoch: 60 Train loss: 0.044897 Validation loss: 0.067986
# Epoch: 61 Train loss: 0.03759 Validation loss: 0.082157
# Epoch: 62 Train loss: 0.033714 Validation loss: 0.085124
# Epoch: 63 Train loss: 0.031441 Validation loss: 0.084093
# Epoch: 64 Train loss: 0.029831 Validation loss: 0.081897
# Epoch: 65 Train loss: 0.028516 Validation loss: 0.079491
# Epoch: 66 Train loss: 0.027355 Validation loss: 0.077199
# Epoch: 67 Train loss: 0.026294 Validation loss: 0.075113
# Epoch: 68 Train loss: 0.025312 Validation loss: 0.073251
# Epoch: 69 Train loss: 0.024398 Validation loss: 0.071599
# Epoch: 70 Train loss: 0.023543 Validation loss: 0.070134
# Epoch: 71 Train loss: 0.022743 Validation loss: 0.068831
# Epoch: 72 Train loss: 0.021994 Validation loss: 0.067664
# Epoch: 73 Train loss: 0.021292 Validation loss: 0.066618
# Epoch: 74 Train loss: 0.020633 Validation loss: 0.065673
# Epoch: 75 Train loss: 0.020014 Validation loss: 0.064813
# Epoch: 76 Train loss: 0.019434 Validation loss: 0.064027
# Epoch: 77 Train loss: 0.018888 Validation loss: 0.063305
# Epoch: 78 Train loss: 0.018375 Validation loss: 0.062638
# Epoch: 79 Train loss: 0.017893 Validation loss: 0.062018
# Epoch: 80 Train loss: 0.017439 Validation loss: 0.06144
# Epoch: 81 Train loss: 0.017011 Validation loss: 0.0609
# Epoch: 82 Train loss: 0.016609 Validation loss: 0.060388
# Epoch: 83 Train loss: 0.01623 Validation loss: 0.059906
# Epoch: 84 Train loss: 0.015873 Validation loss: 0.059452
# Epoch: 85 Train loss: 0.015536 Validation loss: 0.059019
# Epoch: 86 Train loss: 0.015218 Validation loss: 0.058607
# Epoch: 87 Train loss: 0.014917 Validation loss: 0.058215
# Epoch: 88 Train loss: 0.014634 Validation loss: 0.057839
# Epoch: 89 Train loss: 0.014366 Validation loss: 0.05748
# Epoch: 90 Train loss: 0.014113 Validation loss: 0.057136
# Epoch: 91 Train loss: 0.013873 Validation loss: 0.056806
# Epoch: 92 Train loss: 0.013646 Validation loss: 0.056489
# Epoch: 93 Train loss: 0.013431 Validation loss: 0.056184
# Epoch: 94 Train loss: 0.013228 Validation loss: 0.055891
# Epoch: 95 Train loss: 0.013035 Validation loss: 0.055609
# Epoch: 96 Train loss: 0.012852 Validation loss: 0.055338
# Epoch: 97 Train loss: 0.012678 Validation loss: 0.055075
# Epoch: 98 Train loss: 0.012513 Validation loss: 0.054823
# Epoch: 99 Train loss: 0.012356 Validation loss: 0.054579
# Epoch: 100 Train loss: 0.012207 Validation loss: 0.054345
# Epoch: 101 Train loss: 0.012065 Validation loss: 0.054117
# Epoch: 102 Train loss: 0.01193 Validation loss: 0.053899
# Epoch: 103 Train loss: 0.011801 Validation loss: 0.053688
# Epoch: 104 Train loss: 0.011678 Validation loss: 0.053484
# Epoch: 105 Train loss: 0.011561 Validation loss: 0.053287
# Epoch: 106 Train loss: 0.011449 Validation loss: 0.053098
# Epoch: 107 Train loss: 0.011342 Validation loss: 0.052913
# Epoch: 108 Train loss: 0.01124 Validation loss: 0.052736
# Epoch: 109 Train loss: 0.011142 Validation loss: 0.052565
# Epoch: 110 Train loss: 0.011049 Validation loss: 0.052399
# Epoch: 111 Train loss: 0.010959 Validation loss: 0.05224
# Epoch: 112 Train loss: 0.010874 Validation loss: 0.052086
# Epoch: 113 Train loss: 0.010791 Validation loss: 0.051935
# Epoch: 114 Train loss: 0.010712 Validation loss: 0.05179
# Epoch: 115 Train loss: 0.010636 Validation loss: 0.051651
# Epoch: 116 Train loss: 0.010563 Validation loss: 0.051517
# Epoch: 117 Train loss: 0.010493 Validation loss: 0.051385
# Epoch: 118 Train loss: 0.010426 Validation loss: 0.051258
# Epoch: 119 Train loss: 0.01036 Validation loss: 0.051136
# Epoch: 120 Train loss: 0.010298 Validation loss: 0.051018
# Epoch: 121 Train loss: 0.010237 Validation loss: 0.050903
# Epoch: 122 Train loss: 0.010179 Validation loss: 0.050791
# Epoch: 123 Train loss: 0.010123 Validation loss: 0.050683
# Epoch: 124 Train loss: 0.010068 Validation loss: 0.050578
# Epoch: 125 Train loss: 0.010016 Validation loss: 0.050478
# Epoch: 126 Train loss: 0.0099646 Validation loss: 0.050381
# Epoch: 127 Train loss: 0.0099153 Validation loss: 0.050285
# Epoch: 128 Train loss: 0.0098675 Validation loss: 0.050195
# Epoch: 129 Train loss: 0.0098212 Validation loss: 0.050105
# Epoch: 130 Train loss: 0.0097762 Validation loss: 0.050019
# Epoch: 131 Train loss: 0.0097326 Validation loss: 0.049936
# Epoch: 132 Train loss: 0.0096902 Validation loss: 0.049854
# Epoch: 133 Train loss: 0.009649 Validation loss: 0.049775
# Epoch: 134 Train loss: 0.009609 Validation loss: 0.049697
# Epoch: 135 Train loss: 0.00957 Validation loss: 0.049623
# Epoch: 136 Train loss: 0.009532 Validation loss: 0.049551
# Epoch: 137 Train loss: 0.009495 Validation loss: 0.049481
# Epoch: 138 Train loss: 0.0094589 Validation loss: 0.049414
# Epoch: 139 Train loss: 0.0094238 Validation loss: 0.049348
# Epoch: 140 Train loss: 0.0093894 Validation loss: 0.049283
# Epoch: 141 Train loss: 0.0093559 Validation loss: 0.04922
# Epoch: 142 Train loss: 0.0093232 Validation loss: 0.049159
# Epoch: 143 Train loss: 0.0092911 Validation loss: 0.049099
# Epoch: 144 Train loss: 0.0092598 Validation loss: 0.04904
# Epoch: 145 Train loss: 0.0092292 Validation loss: 0.048982
# Epoch: 146 Train loss: 0.0091992 Validation loss: 0.048927
# Epoch: 147 Train loss: 0.0091698 Validation loss: 0.048873
# Epoch: 148 Train loss: 0.009141 Validation loss: 0.048821
# Epoch: 149 Train loss: 0.0091128 Validation loss: 0.04877
# Epoch: 150 Train loss: 0.0090851 Validation loss: 0.048719
# Epoch: 151 Train loss: 0.0090579 Validation loss: 0.048669
# Epoch: 152 Train loss: 0.0090312 Validation loss: 0.048621
# Epoch: 153 Train loss: 0.009005 Validation loss: 0.048575
# Epoch: 154 Train loss: 0.0089792 Validation loss: 0.048529
# Epoch: 155 Train loss: 0.0089539 Validation loss: 0.048484
# Epoch: 156 Train loss: 0.0089291 Validation loss: 0.048438
# Epoch: 157 Train loss: 0.0089046 Validation loss: 0.048395
# Epoch: 158 Train loss: 0.0088805 Validation loss: 0.048352
# Epoch: 159 Train loss: 0.0088568 Validation loss: 0.048309
# Epoch: 160 Train loss: 0.0088334 Validation loss: 0.048268
# Epoch: 161 Train loss: 0.0088104 Validation loss: 0.048227
# Epoch: 162 Train loss: 0.0087878 Validation loss: 0.048187
# Epoch: 163 Train loss: 0.0087654 Validation loss: 0.048148
# Epoch: 164 Train loss: 0.0087434 Validation loss: 0.04811
# Epoch: 165 Train loss: 0.0087217 Validation loss: 0.048072
# Epoch: 166 Train loss: 0.0087003 Validation loss: 0.048035
# Epoch: 167 Train loss: 0.0086791 Validation loss: 0.047997
# Epoch: 168 Train loss: 0.0086582 Validation loss: 0.047961
# Epoch: 169 Train loss: 0.0086376 Validation loss: 0.047925
# Epoch: 170 Train loss: 0.0086173 Validation loss: 0.047889
# Epoch: 171 Train loss: 0.0085972 Validation loss: 0.047854
# Epoch: 172 Train loss: 0.0085774 Validation loss: 0.04782
# Epoch: 173 Train loss: 0.0085577 Validation loss: 0.047786
# Epoch: 174 Train loss: 0.0085383 Validation loss: 0.047751
# Epoch: 175 Train loss: 0.0085192 Validation loss: 0.047716
# Epoch: 176 Train loss: 0.0085002 Validation loss: 0.047684
# Epoch: 177 Train loss: 0.0084815 Validation loss: 0.047651
# Epoch: 178 Train loss: 0.008463 Validation loss: 0.047618
# Epoch: 179 Train loss: 0.0084446 Validation loss: 0.047585
# Epoch: 180 Train loss: 0.0084265 Validation loss: 0.047552
# Epoch: 181 Train loss: 0.0084085 Validation loss: 0.04752
# Epoch: 182 Train loss: 0.0083908 Validation loss: 0.047489
# Epoch: 183 Train loss: 0.0083732 Validation loss: 0.047456
# Epoch: 184 Train loss: 0.0083558 Validation loss: 0.047424
# Epoch: 185 Train loss: 0.0083385 Validation loss: 0.047393
# Epoch: 186 Train loss: 0.0083214 Validation loss: 0.047361
# Epoch: 187 Train loss: 0.0083045 Validation loss: 0.04733
# Epoch: 188 Train loss: 0.0082878 Validation loss: 0.047298
# Epoch: 189 Train loss: 0.0082712 Validation loss: 0.047267
# Epoch: 190 Train loss: 0.0082548 Validation loss: 0.047235
# Epoch: 191 Train loss: 0.0082385 Validation loss: 0.047204
# Epoch: 192 Train loss: 0.0082223 Validation loss: 0.047174
# Epoch: 193 Train loss: 0.0082063 Validation loss: 0.047142
# Epoch: 194 Train loss: 0.0081905 Validation loss: 0.047112
# Epoch: 195 Train loss: 0.0081748 Validation loss: 0.047082
# Epoch: 196 Train loss: 0.0081592 Validation loss: 0.047051
# Epoch: 197 Train loss: 0.0081437 Validation loss: 0.04702
# Epoch: 198 Train loss: 0.0081284 Validation loss: 0.046991
# Epoch: 199 Train loss: 0.0081132 Validation loss: 0.04696
# Epoch: 200 Train loss: 0.0080982 Validation loss: 0.046929
# Epoch: 201 Train loss: 0.0080832 Validation loss: 0.046898
# Epoch: 202 Train loss: 0.0080684 Validation loss: 0.046868
# Epoch: 203 Train loss: 0.0080537 Validation loss: 0.046838
# Epoch: 204 Train loss: 0.0080391 Validation loss: 0.046809
# Epoch: 205 Train loss: 0.0080247 Validation loss: 0.046779
# Epoch: 206 Train loss: 0.0080103 Validation loss: 0.046748
# Epoch: 207 Train loss: 0.0079961 Validation loss: 0.046718
# Epoch: 208 Train loss: 0.007982 Validation loss: 0.046689
# Epoch: 209 Train loss: 0.0079679 Validation loss: 0.04666
# Epoch: 210 Train loss: 0.0079541 Validation loss: 0.046629
# Epoch: 211 Train loss: 0.0079403 Validation loss: 0.046599
# Epoch: 212 Train loss: 0.0079266 Validation loss: 0.046569
# Epoch: 213 Train loss: 0.007913 Validation loss: 0.046539
# Epoch: 214 Train loss: 0.0078995 Validation loss: 0.046509
# Epoch: 215 Train loss: 0.0078861 Validation loss: 0.046479
# Epoch: 216 Train loss: 0.0078728 Validation loss: 0.04645
# Epoch: 217 Train loss: 0.0078596 Validation loss: 0.046419
# Epoch: 218 Train loss: 0.0078465 Validation loss: 0.046389
# Epoch: 219 Train loss: 0.0078336 Validation loss: 0.046359
# Epoch: 220 Train loss: 0.0078206 Validation loss: 0.046328
# Epoch: 221 Train loss: 0.0078078 Validation loss: 0.046299
# Epoch: 222 Train loss: 0.0077951 Validation loss: 0.046269
# Epoch: 223 Train loss: 0.0077825 Validation loss: 0.046239
# Epoch: 224 Train loss: 0.0077699 Validation loss: 0.046209
# Epoch: 225 Train loss: 0.0077575 Validation loss: 0.04618
# Epoch: 226 Train loss: 0.0077451 Validation loss: 0.046149
# Epoch: 227 Train loss: 0.0077329 Validation loss: 0.046119
# Epoch: 228 Train loss: 0.0077207 Validation loss: 0.04609
# Epoch: 229 Train loss: 0.0077086 Validation loss: 0.04606
# Epoch: 230 Train loss: 0.0076966 Validation loss: 0.04603
# Epoch: 231 Train loss: 0.0076846 Validation loss: 0.046001
# Epoch: 232 Train loss: 0.0076728 Validation loss: 0.04597
# Epoch: 233 Train loss: 0.007661 Validation loss: 0.04594
# Epoch: 234 Train loss: 0.0076493 Validation loss: 0.04591
# Epoch: 235 Train loss: 0.0076377 Validation loss: 0.04588
# Epoch: 236 Train loss: 0.0076262 Validation loss: 0.04585
# Epoch: 237 Train loss: 0.0076147 Validation loss: 0.04582
# Epoch: 238 Train loss: 0.0076033 Validation loss: 0.045789
# Epoch: 239 Train loss: 0.0075921 Validation loss: 0.045759
# Epoch: 240 Train loss: 0.0075808 Validation loss: 0.045729
# Epoch: 241 Train loss: 0.0075697 Validation loss: 0.045699
# Epoch: 242 Train loss: 0.0075586 Validation loss: 0.045669
# Epoch: 243 Train loss: 0.0075476 Validation loss: 0.045639
# Epoch: 244 Train loss: 0.0075367 Validation loss: 0.045609
# Epoch: 245 Train loss: 0.0075258 Validation loss: 0.045578
# Epoch: 246 Train loss: 0.007515 Validation loss: 0.045549
# Epoch: 247 Train loss: 0.0075043 Validation loss: 0.045518
# Epoch: 248 Train loss: 0.0074937 Validation loss: 0.045488
# Epoch: 249 Train loss: 0.0074831 Validation loss: 0.045458
# Epoch: 250 Train loss: 0.0074726 Validation loss: 0.045427
# Epoch: 251 Train loss: 0.0074621 Validation loss: 0.045397
# Epoch: 252 Train loss: 0.0074518 Validation loss: 0.045368
# Epoch: 253 Train loss: 0.0074414 Validation loss: 0.045337
# Epoch: 254 Train loss: 0.0074312 Validation loss: 0.045308
# Epoch: 255 Train loss: 0.007421 Validation loss: 0.045277
# Epoch: 256 Train loss: 0.0074109 Validation loss: 0.045247
# Epoch: 257 Train loss: 0.0074009 Validation loss: 0.045217
# Epoch: 258 Train loss: 0.0073909 Validation loss: 0.045187
# Epoch: 259 Train loss: 0.007381 Validation loss: 0.045157
# Epoch: 260 Train loss: 0.0073711 Validation loss: 0.045127
# Epoch: 261 Train loss: 0.0073613 Validation loss: 0.045097
# Epoch: 262 Train loss: 0.0073516 Validation loss: 0.045067
# Epoch: 263 Train loss: 0.0073419 Validation loss: 0.045038
# Epoch: 264 Train loss: 0.0073323 Validation loss: 0.045008
# Epoch: 265 Train loss: 0.0073227 Validation loss: 0.044978
# Epoch: 266 Train loss: 0.0073132 Validation loss: 0.044947
# Epoch: 267 Train loss: 0.0073038 Validation loss: 0.044917
# Epoch: 268 Train loss: 0.0072944 Validation loss: 0.044887
# Epoch: 269 Train loss: 0.0072851 Validation loss: 0.044857
# Epoch: 270 Train loss: 0.0072759 Validation loss: 0.044828
# Epoch: 271 Train loss: 0.0072667 Validation loss: 0.044798
# Epoch: 272 Train loss: 0.0072575 Validation loss: 0.044768
# Epoch: 273 Train loss: 0.0072485 Validation loss: 0.044738
# Epoch: 274 Train loss: 0.0072394 Validation loss: 0.044708
# Epoch: 275 Train loss: 0.0072304 Validation loss: 0.044679
# Epoch: 276 Train loss: 0.0072215 Validation loss: 0.044648
# Epoch: 277 Train loss: 0.0072127 Validation loss: 0.044619
# Epoch: 278 Train loss: 0.0072039 Validation loss: 0.044589
# Epoch: 279 Train loss: 0.0071951 Validation loss: 0.04456
# Epoch: 280 Train loss: 0.0071864 Validation loss: 0.04453
# Epoch: 281 Train loss: 0.0071777 Validation loss: 0.044502
# Epoch: 282 Train loss: 0.0071691 Validation loss: 0.044472
# Epoch: 283 Train loss: 0.0071606 Validation loss: 0.044443
# Epoch: 284 Train loss: 0.0071521 Validation loss: 0.044413
# Epoch: 285 Train loss: 0.0071437 Validation loss: 0.044385
# Epoch: 286 Train loss: 0.0071353 Validation loss: 0.044356
# Epoch: 287 Train loss: 0.0071269 Validation loss: 0.044326
# Epoch: 288 Train loss: 0.0071186 Validation loss: 0.044297
# Epoch: 289 Train loss: 0.0071104 Validation loss: 0.044268
# Epoch: 290 Train loss: 0.0071022 Validation loss: 0.044239
# Epoch: 291 Train loss: 0.007094 Validation loss: 0.04421
# Epoch: 292 Train loss: 0.0070859 Validation loss: 0.044181
# Epoch: 293 Train loss: 0.0070779 Validation loss: 0.044153
# Epoch: 294 Train loss: 0.0070699 Validation loss: 0.044124
# Epoch: 295 Train loss: 0.0070619 Validation loss: 0.044097
# Epoch: 296 Train loss: 0.007054 Validation loss: 0.044069
# Epoch: 297 Train loss: 0.0070462 Validation loss: 0.04404
# Epoch: 298 Train loss: 0.0070383 Validation loss: 0.044012
# Epoch: 299 Train loss: 0.0070306 Validation loss: 0.043983
# Epoch: 300 Train loss: 0.0070228 Validation loss: 0.043955
# Epoch: 301 Train loss: 0.0070152 Validation loss: 0.043927
# Epoch: 302 Train loss: 0.0070075 Validation loss: 0.043899
# Epoch: 303 Train loss: 0.0069999 Validation loss: 0.043871
# Epoch: 304 Train loss: 0.0069924 Validation loss: 0.043844
# Epoch: 305 Train loss: 0.0069849 Validation loss: 0.043816
# Epoch: 306 Train loss: 0.0069774 Validation loss: 0.043788
# Epoch: 307 Train loss: 0.00697 Validation loss: 0.04376
# Epoch: 308 Train loss: 0.0069626 Validation loss: 0.043733
# Epoch: 309 Train loss: 0.0069553 Validation loss: 0.043706
# Epoch: 310 Train loss: 0.006948 Validation loss: 0.043678
# Epoch: 311 Train loss: 0.0069408 Validation loss: 0.043651
# Epoch: 312 Train loss: 0.0069335 Validation loss: 0.043624
# Epoch: 313 Train loss: 0.0069264 Validation loss: 0.043597
# Epoch: 314 Train loss: 0.0069193 Validation loss: 0.04357
# Epoch: 315 Train loss: 0.0069122 Validation loss: 0.043543
# Epoch: 316 Train loss: 0.0069052 Validation loss: 0.043516
# Epoch: 317 Train loss: 0.0068982 Validation loss: 0.04349
# Epoch: 318 Train loss: 0.0068912 Validation loss: 0.043462
# Epoch: 319 Train loss: 0.0068843 Validation loss: 0.043436
# Epoch: 320 Train loss: 0.0068774 Validation loss: 0.04341
# Epoch: 321 Train loss: 0.0068705 Validation loss: 0.043383
# Epoch: 322 Train loss: 0.0068637 Validation loss: 0.043356
# Epoch: 323 Train loss: 0.006857 Validation loss: 0.04333
# Epoch: 324 Train loss: 0.0068503 Validation loss: 0.043304
# Epoch: 325 Train loss: 0.0068435 Validation loss: 0.043279
# Epoch: 326 Train loss: 0.0068369 Validation loss: 0.043252
# Epoch: 327 Train loss: 0.0068303 Validation loss: 0.043226
# Epoch: 328 Train loss: 0.0068237 Validation loss: 0.043201
# Epoch: 329 Train loss: 0.0068172 Validation loss: 0.043175
# Epoch: 330 Train loss: 0.0068107 Validation loss: 0.043149
# Epoch: 331 Train loss: 0.0068042 Validation loss: 0.043124
# Epoch: 332 Train loss: 0.0067977 Validation loss: 0.043098
# Epoch: 333 Train loss: 0.0067914 Validation loss: 0.043072
# Epoch: 334 Train loss: 0.006785 Validation loss: 0.043047
# Epoch: 335 Train loss: 0.0067787 Validation loss: 0.043021
# Epoch: 336 Train loss: 0.0067724 Validation loss: 0.042996
# Epoch: 337 Train loss: 0.0067661 Validation loss: 0.042971
# Epoch: 338 Train loss: 0.0067599 Validation loss: 0.042946
# Epoch: 339 Train loss: 0.0067537 Validation loss: 0.042921
# Epoch: 340 Train loss: 0.0067476 Validation loss: 0.042896
# Epoch: 341 Train loss: 0.0067414 Validation loss: 0.042871
# Epoch: 342 Train loss: 0.0067354 Validation loss: 0.042847
# Epoch: 343 Train loss: 0.0067293 Validation loss: 0.042822
# Epoch: 344 Train loss: 0.0067233 Validation loss: 0.042798
# Epoch: 345 Train loss: 0.0067173 Validation loss: 0.042774
# Epoch: 346 Train loss: 0.0067114 Validation loss: 0.04275
# Epoch: 347 Train loss: 0.0067054 Validation loss: 0.042726
# Epoch: 348 Train loss: 0.0066995 Validation loss: 0.042701
# Epoch: 349 Train loss: 0.0066937 Validation loss: 0.042678
# Epoch: 350 Train loss: 0.0066878 Validation loss: 0.042654
# Epoch: 351 Train loss: 0.0066821 Validation loss: 0.04263
# Epoch: 352 Train loss: 0.0066763 Validation loss: 0.042607
# Epoch: 353 Train loss: 0.0066706 Validation loss: 0.042582
# Epoch: 354 Train loss: 0.0066649 Validation loss: 0.042559
# Epoch: 355 Train loss: 0.0066592 Validation loss: 0.042535
# Epoch: 356 Train loss: 0.0066536 Validation loss: 0.042512
# Epoch: 357 Train loss: 0.0066479 Validation loss: 0.042487
# Epoch: 358 Train loss: 0.0066424 Validation loss: 0.042464
# Epoch: 359 Train loss: 0.0066368 Validation loss: 0.042441
# Epoch: 360 Train loss: 0.0066313 Validation loss: 0.042418
# Epoch: 361 Train loss: 0.0066258 Validation loss: 0.042395
# Epoch: 362 Train loss: 0.0066204 Validation loss: 0.042372
# Epoch: 363 Train loss: 0.0066149 Validation loss: 0.042349
# Epoch: 364 Train loss: 0.0066095 Validation loss: 0.042326
# Epoch: 365 Train loss: 0.0066041 Validation loss: 0.042304
# Epoch: 366 Train loss: 0.0065988 Validation loss: 0.042281
# Epoch: 367 Train loss: 0.0065935 Validation loss: 0.042259
# Epoch: 368 Train loss: 0.0065882 Validation loss: 0.042236
# Epoch: 369 Train loss: 0.0065829 Validation loss: 0.042215
# Epoch: 370 Train loss: 0.0065777 Validation loss: 0.042192
# Epoch: 371 Train loss: 0.0065725 Validation loss: 0.042171
# Epoch: 372 Train loss: 0.0065673 Validation loss: 0.042149
# Epoch: 373 Train loss: 0.0065622 Validation loss: 0.042128
# Epoch: 374 Train loss: 0.006557 Validation loss: 0.042106
# Epoch: 375 Train loss: 0.0065519 Validation loss: 0.042084
# Epoch: 376 Train loss: 0.0065469 Validation loss: 0.042064
# Epoch: 377 Train loss: 0.0065418 Validation loss: 0.042043
# Epoch: 378 Train loss: 0.0065368 Validation loss: 0.042022
# Epoch: 379 Train loss: 0.0065318 Validation loss: 0.042001
# Epoch: 380 Train loss: 0.0065268 Validation loss: 0.041981
# Epoch: 381 Train loss: 0.0065219 Validation loss: 0.04196
# Epoch: 382 Train loss: 0.006517 Validation loss: 0.041939
# Epoch: 383 Train loss: 0.0065121 Validation loss: 0.041919
# Epoch: 384 Train loss: 0.0065072 Validation loss: 0.041899
# Epoch: 385 Train loss: 0.0065024 Validation loss: 0.041878
# Epoch: 386 Train loss: 0.0064975 Validation loss: 0.041859
# Epoch: 387 Train loss: 0.0064928 Validation loss: 0.041839
# Epoch: 388 Train loss: 0.006488 Validation loss: 0.041819
# Epoch: 389 Train loss: 0.0064832 Validation loss: 0.0418
# Epoch: 390 Train loss: 0.0064785 Validation loss: 0.04178
# Epoch: 391 Train loss: 0.0064738 Validation loss: 0.04176
# Epoch: 392 Train loss: 0.0064692 Validation loss: 0.041741
# Epoch: 393 Train loss: 0.0064645 Validation loss: 0.041722
# Epoch: 394 Train loss: 0.0064599 Validation loss: 0.041703
# Epoch: 395 Train loss: 0.0064553 Validation loss: 0.041684
# Epoch: 396 Train loss: 0.0064507 Validation loss: 0.041665
# Epoch: 397 Train loss: 0.0064462 Validation loss: 0.041646
# Epoch: 398 Train loss: 0.0064417 Validation loss: 0.041627
# Epoch: 399 Train loss: 0.0064372 Validation loss: 0.041608
# Epoch: 400 Train loss: 0.0064327 Validation loss: 0.041589
# Epoch: 401 Train loss: 0.0064282 Validation loss: 0.04157
# Epoch: 402 Train loss: 0.0064238 Validation loss: 0.041552
# Epoch: 403 Train loss: 0.0064193 Validation loss: 0.041533
# Epoch: 404 Train loss: 0.006415 Validation loss: 0.041515
# Epoch: 405 Train loss: 0.0064106 Validation loss: 0.041497
# Epoch: 406 Train loss: 0.0064062 Validation loss: 0.041479
# Epoch: 407 Train loss: 0.0064019 Validation loss: 0.04146
# Epoch: 408 Train loss: 0.0063976 Validation loss: 0.041442
# Epoch: 409 Train loss: 0.0063933 Validation loss: 0.041425
# Epoch: 410 Train loss: 0.0063891 Validation loss: 0.041408
# Epoch: 411 Train loss: 0.0063848 Validation loss: 0.04139
# Epoch: 412 Train loss: 0.0063806 Validation loss: 0.041373
# Epoch: 413 Train loss: 0.0063764 Validation loss: 0.041356
# Epoch: 414 Train loss: 0.0063722 Validation loss: 0.041338
# Epoch: 415 Train loss: 0.006368 Validation loss: 0.041321
# Epoch: 416 Train loss: 0.0063639 Validation loss: 0.041304
# Epoch: 417 Train loss: 0.0063598 Validation loss: 0.041287
# Epoch: 418 Train loss: 0.0063557 Validation loss: 0.041271
# Epoch: 419 Train loss: 0.0063516 Validation loss: 0.041253
# Epoch: 420 Train loss: 0.0063476 Validation loss: 0.041236
# Epoch: 421 Train loss: 0.0063435 Validation loss: 0.04122
# Epoch: 422 Train loss: 0.0063395 Validation loss: 0.041203
# Epoch: 423 Train loss: 0.0063355 Validation loss: 0.041186
# Epoch: 424 Train loss: 0.0063315 Validation loss: 0.04117
# Epoch: 425 Train loss: 0.0063276 Validation loss: 0.041154
# Epoch: 426 Train loss: 0.0063236 Validation loss: 0.041137
# Epoch: 427 Train loss: 0.0063197 Validation loss: 0.041121
# Epoch: 428 Train loss: 0.0063158 Validation loss: 0.041105
# Epoch: 429 Train loss: 0.0063119 Validation loss: 0.04109
# Epoch: 430 Train loss: 0.0063081 Validation loss: 0.041074
# Epoch: 431 Train loss: 0.0063042 Validation loss: 0.041058
# Epoch: 432 Train loss: 0.0063004 Validation loss: 0.041043
# Epoch: 433 Train loss: 0.0062966 Validation loss: 0.041028
# Epoch: 434 Train loss: 0.0062928 Validation loss: 0.041012
# Epoch: 435 Train loss: 0.006289 Validation loss: 0.040998
# Epoch: 436 Train loss: 0.0062853 Validation loss: 0.040982
# Epoch: 437 Train loss: 0.0062815 Validation loss: 0.040969
# Epoch: 438 Train loss: 0.0062778 Validation loss: 0.040953
# Epoch: 439 Train loss: 0.0062741 Validation loss: 0.040939
# Epoch: 440 Train loss: 0.0062704 Validation loss: 0.040923
# Epoch: 441 Train loss: 0.0062668 Validation loss: 0.040908
# Epoch: 442 Train loss: 0.0062631 Validation loss: 0.040895
# Epoch: 443 Train loss: 0.0062595 Validation loss: 0.04088
# Epoch: 444 Train loss: 0.0062559 Validation loss: 0.040866
# Epoch: 445 Train loss: 0.0062523 Validation loss: 0.040852
# Epoch: 446 Train loss: 0.0062487 Validation loss: 0.040838
# Epoch: 447 Train loss: 0.0062452 Validation loss: 0.040823
# Epoch: 448 Train loss: 0.0062416 Validation loss: 0.04081
# Epoch: 449 Train loss: 0.0062381 Validation loss: 0.040796
# Epoch: 450 Train loss: 0.0062346 Validation loss: 0.040782
# Epoch: 451 Train loss: 0.0062311 Validation loss: 0.040768
# Epoch: 452 Train loss: 0.0062276 Validation loss: 0.040756
# Epoch: 453 Train loss: 0.0062241 Validation loss: 0.040741
# Epoch: 454 Train loss: 0.0062207 Validation loss: 0.040728
# Epoch: 455 Train loss: 0.0062173 Validation loss: 0.040715
# Epoch: 456 Train loss: 0.0062138 Validation loss: 0.040702
# Epoch: 457 Train loss: 0.0062105 Validation loss: 0.040689
# Epoch: 458 Train loss: 0.0062071 Validation loss: 0.040676
# Epoch: 459 Train loss: 0.0062037 Validation loss: 0.040664
# Epoch: 460 Train loss: 0.0062004 Validation loss: 0.04065
# Epoch: 461 Train loss: 0.006197 Validation loss: 0.040638
# Epoch: 462 Train loss: 0.0061937 Validation loss: 0.040625
# Epoch: 463 Train loss: 0.0061904 Validation loss: 0.040613
# Epoch: 464 Train loss: 0.0061871 Validation loss: 0.040601
# Epoch: 465 Train loss: 0.0061839 Validation loss: 0.040589
# Epoch: 466 Train loss: 0.0061806 Validation loss: 0.040577
# Epoch: 467 Train loss: 0.0061773 Validation loss: 0.040564
# Epoch: 468 Train loss: 0.0061741 Validation loss: 0.040552
# Epoch: 469 Train loss: 0.0061709 Validation loss: 0.040541
# Epoch: 470 Train loss: 0.0061677 Validation loss: 0.040529
# Epoch: 471 Train loss: 0.0061645 Validation loss: 0.040517
# Epoch: 472 Train loss: 0.0061614 Validation loss: 0.040505
# Epoch: 473 Train loss: 0.0061582 Validation loss: 0.040495
# Epoch: 474 Train loss: 0.0061551 Validation loss: 0.040483
# Epoch: 475 Train loss: 0.0061519 Validation loss: 0.040472
# Epoch: 476 Train loss: 0.0061488 Validation loss: 0.040461
# Epoch: 477 Train loss: 0.0061457 Validation loss: 0.040449
# Epoch: 478 Train loss: 0.0061427 Validation loss: 0.040438
# Epoch: 479 Train loss: 0.0061396 Validation loss: 0.040427
# Epoch: 480 Train loss: 0.0061365 Validation loss: 0.040417
# Epoch: 481 Train loss: 0.0061335 Validation loss: 0.040407
# Epoch: 482 Train loss: 0.0061305 Validation loss: 0.040395
# Epoch: 483 Train loss: 0.0061274 Validation loss: 0.040385
# Epoch: 484 Train loss: 0.0061244 Validation loss: 0.040375
# Epoch: 485 Train loss: 0.0061214 Validation loss: 0.040365
# Epoch: 486 Train loss: 0.0061185 Validation loss: 0.040355
# Epoch: 487 Train loss: 0.0061155 Validation loss: 0.040346
# Epoch: 488 Train loss: 0.0061126 Validation loss: 0.040335
# Epoch: 489 Train loss: 0.0061096 Validation loss: 0.040325
# Epoch: 490 Train loss: 0.0061067 Validation loss: 0.040316
# Epoch: 491 Train loss: 0.0061038 Validation loss: 0.040306
# Epoch: 492 Train loss: 0.0061009 Validation loss: 0.040296
# Epoch: 493 Train loss: 0.006098 Validation loss: 0.040287
# Epoch: 494 Train loss: 0.0060951 Validation loss: 0.040277
# Epoch: 495 Train loss: 0.0060923 Validation loss: 0.040267
# Epoch: 496 Train loss: 0.0060894 Validation loss: 0.040258
# Epoch: 497 Train loss: 0.0060866 Validation loss: 0.040249
# Epoch: 498 Train loss: 0.0060838 Validation loss: 0.04024
# Epoch: 499 Train loss: 0.006081 Validation loss: 0.040231
# Epoch: 500 Train loss: 0.0060782 Validation loss: 0.040222
# Epoch: 501 Train loss: 0.0060754 Validation loss: 0.040213
# Epoch: 502 Train loss: 0.0060726 Validation loss: 0.040205
# Epoch: 503 Train loss: 0.0060699 Validation loss: 0.040195
# Epoch: 504 Train loss: 0.0060671 Validation loss: 0.040186
# Epoch: 505 Train loss: 0.0060644 Validation loss: 0.040178
# Epoch: 506 Train loss: 0.0060617 Validation loss: 0.04017
# Epoch: 507 Train loss: 0.006059 Validation loss: 0.040162
# Epoch: 508 Train loss: 0.0060563 Validation loss: 0.040153
# Epoch: 509 Train loss: 0.0060536 Validation loss: 0.040146
# Epoch: 510 Train loss: 0.0060509 Validation loss: 0.040137
# Epoch: 511 Train loss: 0.0060482 Validation loss: 0.040129
# Epoch: 512 Train loss: 0.0060456 Validation loss: 0.040122
# Epoch: 513 Train loss: 0.0060429 Validation loss: 0.040114
# Epoch: 514 Train loss: 0.0060403 Validation loss: 0.040106
# Epoch: 515 Train loss: 0.0060377 Validation loss: 0.040099
# Epoch: 516 Train loss: 0.0060351 Validation loss: 0.040092
# Epoch: 517 Train loss: 0.0060325 Validation loss: 0.040084
# Epoch: 518 Train loss: 0.0060299 Validation loss: 0.040077
# Epoch: 519 Train loss: 0.0060273 Validation loss: 0.040069
# Epoch: 520 Train loss: 0.0060248 Validation loss: 0.040063
# Epoch: 521 Train loss: 0.0060222 Validation loss: 0.040055
# Epoch: 522 Train loss: 0.0060197 Validation loss: 0.040047
# Epoch: 523 Train loss: 0.0060171 Validation loss: 0.04004
# Epoch: 524 Train loss: 0.0060146 Validation loss: 0.040034
# Epoch: 525 Train loss: 0.0060121 Validation loss: 0.040027
# Epoch: 526 Train loss: 0.0060096 Validation loss: 0.04002
# Epoch: 527 Train loss: 0.0060071 Validation loss: 0.040014
# Epoch: 528 Train loss: 0.0060047 Validation loss: 0.040007
# Epoch: 529 Train loss: 0.0060022 Validation loss: 0.04
# Epoch: 530 Train loss: 0.0059997 Validation loss: 0.039994
# Epoch: 531 Train loss: 0.0059973 Validation loss: 0.039988
# Epoch: 532 Train loss: 0.0059949 Validation loss: 0.039981
# Epoch: 533 Train loss: 0.0059924 Validation loss: 0.039975
# Epoch: 534 Train loss: 0.00599 Validation loss: 0.039969
# Epoch: 535 Train loss: 0.0059876 Validation loss: 0.039963
# Epoch: 536 Train loss: 0.0059852 Validation loss: 0.039957
# Epoch: 537 Train loss: 0.0059828 Validation loss: 0.039952
# Epoch: 538 Train loss: 0.0059805 Validation loss: 0.039946
# Epoch: 539 Train loss: 0.0059781 Validation loss: 0.03994
# Epoch: 540 Train loss: 0.0059757 Validation loss: 0.039935
# Epoch: 541 Train loss: 0.0059734 Validation loss: 0.03993
# Epoch: 542 Train loss: 0.0059711 Validation loss: 0.039924
# Epoch: 543 Train loss: 0.0059687 Validation loss: 0.039919
# Epoch: 544 Train loss: 0.0059664 Validation loss: 0.039913
# Epoch: 545 Train loss: 0.0059641 Validation loss: 0.039908
# Epoch: 546 Train loss: 0.0059618 Validation loss: 0.039902
# Epoch: 547 Train loss: 0.0059596 Validation loss: 0.039898
# Epoch: 548 Train loss: 0.0059573 Validation loss: 0.039893
# Epoch: 549 Train loss: 0.005955 Validation loss: 0.039888
# Epoch: 550 Train loss: 0.0059528 Validation loss: 0.039883
# Epoch: 551 Train loss: 0.0059505 Validation loss: 0.039878
# Epoch: 552 Train loss: 0.0059483 Validation loss: 0.039874
# Epoch: 553 Train loss: 0.005946 Validation loss: 0.039869
# Epoch: 554 Train loss: 0.0059438 Validation loss: 0.039864
# Epoch: 555 Train loss: 0.0059416 Validation loss: 0.039859
# Epoch: 556 Train loss: 0.0059394 Validation loss: 0.039855
# Epoch: 557 Train loss: 0.0059372 Validation loss: 0.039851
# Epoch: 558 Train loss: 0.005935 Validation loss: 0.039847
# Epoch: 559 Train loss: 0.0059329 Validation loss: 0.039842
# Epoch: 560 Train loss: 0.0059307 Validation loss: 0.039838
# Epoch: 561 Train loss: 0.0059285 Validation loss: 0.039833
# Epoch: 562 Train loss: 0.0059264 Validation loss: 0.03983
# Epoch: 563 Train loss: 0.0059242 Validation loss: 0.039826
# Epoch: 564 Train loss: 0.0059221 Validation loss: 0.039823
# Epoch: 565 Train loss: 0.00592 Validation loss: 0.039819
# Epoch: 566 Train loss: 0.0059179 Validation loss: 0.039815
# Epoch: 567 Train loss: 0.0059158 Validation loss: 0.039812
# Epoch: 568 Train loss: 0.0059137 Validation loss: 0.039808
# Epoch: 569 Train loss: 0.0059116 Validation loss: 0.039804
# Epoch: 570 Train loss: 0.0059095 Validation loss: 0.039801
# Epoch: 571 Train loss: 0.0059074 Validation loss: 0.039798
# Epoch: 572 Train loss: 0.0059054 Validation loss: 0.039794
# Epoch: 573 Train loss: 0.0059033 Validation loss: 0.03979
# Epoch: 574 Train loss: 0.0059013 Validation loss: 0.039788
# Epoch: 575 Train loss: 0.0058992 Validation loss: 0.039784
# Epoch: 576 Train loss: 0.0058972 Validation loss: 0.039782
# Epoch: 577 Train loss: 0.0058952 Validation loss: 0.039778
# Epoch: 578 Train loss: 0.0058932 Validation loss: 0.039775
# Epoch: 579 Train loss: 0.0058912 Validation loss: 0.039772
# Epoch: 580 Train loss: 0.0058892 Validation loss: 0.039769
# Epoch: 581 Train loss: 0.0058872 Validation loss: 0.039766
# Epoch: 582 Train loss: 0.0058852 Validation loss: 0.039764
# Epoch: 583 Train loss: 0.0058832 Validation loss: 0.03976
# Epoch: 584 Train loss: 0.0058813 Validation loss: 0.039758
# Epoch: 585 Train loss: 0.0058793 Validation loss: 0.039756
# Epoch: 586 Train loss: 0.0058773 Validation loss: 0.039753
# Epoch: 587 Train loss: 0.0058754 Validation loss: 0.03975
# Epoch: 588 Train loss: 0.0058735 Validation loss: 0.039748
# Epoch: 589 Train loss: 0.0058715 Validation loss: 0.039745
# Epoch: 590 Train loss: 0.0058696 Validation loss: 0.039743
# Epoch: 591 Train loss: 0.0058677 Validation loss: 0.03974
# Epoch: 592 Train loss: 0.0058658 Validation loss: 0.039738
# Epoch: 593 Train loss: 0.0058639 Validation loss: 0.039737
# Epoch: 594 Train loss: 0.005862 Validation loss: 0.039734
# Epoch: 595 Train loss: 0.0058601 Validation loss: 0.039732
# Epoch: 596 Train loss: 0.0058582 Validation loss: 0.03973
# Epoch: 597 Train loss: 0.0058564 Validation loss: 0.039728
# Epoch: 598 Train loss: 0.0058545 Validation loss: 0.039726
# Epoch: 599 Train loss: 0.0058526 Validation loss: 0.039725
# Epoch: 600 Train loss: 0.0058508 Validation loss: 0.039723
# Epoch: 601 Train loss: 0.0058489 Validation loss: 0.039722
# Epoch: 602 Train loss: 0.0058471 Validation loss: 0.039721
# Epoch: 603 Train loss: 0.0058453 Validation loss: 0.039719
# Epoch: 604 Train loss: 0.0058435 Validation loss: 0.039717
# Epoch: 605 Train loss: 0.0058416 Validation loss: 0.039715
# Epoch: 606 Train loss: 0.0058398 Validation loss: 0.039714
# Epoch: 607 Train loss: 0.005838 Validation loss: 0.039713
# Epoch: 608 Train loss: 0.0058363 Validation loss: 0.039712
# Epoch: 609 Train loss: 0.0058345 Validation loss: 0.039711
# Epoch: 610 Train loss: 0.0058327 Validation loss: 0.039709
# Epoch: 611 Train loss: 0.0058309 Validation loss: 0.039708
# Epoch: 612 Train loss: 0.0058291 Validation loss: 0.039707
# Epoch: 613 Train loss: 0.0058274 Validation loss: 0.039707
# Epoch: 614 Train loss: 0.0058256 Validation loss: 0.039707
# Epoch: 615 Train loss: 0.0058239 Validation loss: 0.039706
# Epoch: 616 Train loss: 0.0058222 Validation loss: 0.039705
# Epoch: 617 Train loss: 0.0058204 Validation loss: 0.039704
# Epoch: 618 Train loss: 0.0058187 Validation loss: 0.039704
# Epoch: 619 Train loss: 0.005817 Validation loss: 0.039703
# Epoch: 620 Train loss: 0.0058152 Validation loss: 0.039704
# Epoch: 621 Train loss: 0.0058135 Validation loss: 0.039703
# Epoch: 622 Train loss: 0.0058119 Validation loss: 0.039702
# Epoch: 623 Train loss: 0.0058101 Validation loss: 0.039702
# Epoch: 624 Train loss: 0.0058085 Validation loss: 0.039703
# Epoch: 625 Train loss: 0.0058068 Validation loss: 0.039702
# Epoch: 626 Train loss: 0.0058051 Validation loss: 0.039702
# Epoch: 627 Train loss: 0.0058034 Validation loss: 0.039702
# Epoch: 628 Train loss: 0.0058018 Validation loss: 0.039703
# Epoch: 629 Train loss: 0.0058001 Validation loss: 0.039703
# Epoch: 630 Train loss: 0.0057985 Validation loss: 0.039703
# Epoch: 631 Train loss: 0.0057968 Validation loss: 0.039704
# Epoch: 632 Train loss: 0.0057952 Validation loss: 0.039704
# Epoch: 633 Train loss: 0.0057936 Validation loss: 0.039705
# Epoch: 634 Train loss: 0.0057919 Validation loss: 0.039705
# Epoch: 635 Train loss: 0.0057903 Validation loss: 0.039705
# Epoch: 636 Train loss: 0.0057887 Validation loss: 0.039706
# Epoch: 637 Train loss: 0.0057871 Validation loss: 0.039706
# Epoch: 638 Train loss: 0.0057855 Validation loss: 0.039707
# Epoch: 639 Train loss: 0.0057839 Validation loss: 0.039708
# Epoch: 640 Train loss: 0.0057823 Validation loss: 0.039709
# Epoch: 641 Train loss: 0.0057807 Validation loss: 0.03971
# Epoch: 642 Train loss: 0.0057792 Validation loss: 0.039711
# Epoch: 643 Train loss: 0.0057776 Validation loss: 0.039712
# Epoch: 644 Train loss: 0.005776 Validation loss: 0.039711
# Epoch: 645 Train loss: 0.0057744 Validation loss: 0.039714
# Epoch: 646 Train loss: 0.0057729 Validation loss: 0.039714
# Epoch: 647 Train loss: 0.0057713 Validation loss: 0.039716
# Epoch: 648 Train loss: 0.0057698 Validation loss: 0.039716
# Epoch: 649 Train loss: 0.0057683 Validation loss: 0.039718
# Epoch: 650 Train loss: 0.0057667 Validation loss: 0.039719
# Epoch: 651 Train loss: 0.0057652 Validation loss: 0.03972
# Epoch: 652 Train loss: 0.0057637 Validation loss: 0.039721
# Epoch: 653 Train loss: 0.0057622 Validation loss: 0.039723
# Epoch: 654 Train loss: 0.0057607 Validation loss: 0.039725
# Epoch: 655 Train loss: 0.0057591 Validation loss: 0.039726
# Epoch: 656 Train loss: 0.0057576 Validation loss: 0.039727
# Epoch: 657 Train loss: 0.0057562 Validation loss: 0.039728
# Epoch: 658 Train loss: 0.0057547 Validation loss: 0.03973
# Epoch: 659 Train loss: 0.0057532 Validation loss: 0.039732
# Epoch: 660 Train loss: 0.0057517 Validation loss: 0.039733
# Epoch: 661 Train loss: 0.0057502 Validation loss: 0.039735
# Epoch: 662 Train loss: 0.0057487 Validation loss: 0.039737
# Epoch: 663 Train loss: 0.0057473 Validation loss: 0.039739
# Epoch: 664 Train loss: 0.0057458 Validation loss: 0.039741
# Epoch: 665 Train loss: 0.0057444 Validation loss: 0.039744
# Epoch: 666 Train loss: 0.0057429 Validation loss: 0.039745
# Epoch: 667 Train loss: 0.0057415 Validation loss: 0.039747
# Epoch: 668 Train loss: 0.0057401 Validation loss: 0.039749
# Epoch: 669 Train loss: 0.0057386 Validation loss: 0.039751
# Epoch: 670 Train loss: 0.0057372 Validation loss: 0.039754
# Epoch: 671 Train loss: 0.0057358 Validation loss: 0.039756
# Epoch: 672 Train loss: 0.0057344 Validation loss: 0.039758
# Epoch: 673 Train loss: 0.005733 Validation loss: 0.03976
# Epoch: 674 Train loss: 0.0057315 Validation loss: 0.039763
# Epoch: 675 Train loss: 0.0057301 Validation loss: 0.039765
# Epoch: 676 Train loss: 0.0057287 Validation loss: 0.039768
# Epoch: 677 Train loss: 0.0057274 Validation loss: 0.03977
# Epoch: 678 Train loss: 0.005726 Validation loss: 0.039773
# Epoch: 679 Train loss: 0.0057246 Validation loss: 0.039775
# Epoch: 680 Train loss: 0.0057232 Validation loss: 0.039778
# Epoch: 681 Train loss: 0.0057218 Validation loss: 0.039781
# Epoch: 682 Train loss: 0.0057205 Validation loss: 0.039784
# Epoch: 683 Train loss: 0.0057191 Validation loss: 0.039786
# Epoch: 684 Train loss: 0.0057178 Validation loss: 0.03979
# Epoch: 685 Train loss: 0.0057164 Validation loss: 0.039793
# Epoch: 686 Train loss: 0.0057151 Validation loss: 0.039796
# Epoch: 687 Train loss: 0.0057137 Validation loss: 0.039799
# Epoch: 688 Train loss: 0.0057124 Validation loss: 0.039803
# Epoch: 689 Train loss: 0.005711 Validation loss: 0.039805
# Epoch: 690 Train loss: 0.0057097 Validation loss: 0.039809
# Epoch: 691 Train loss: 0.0057084 Validation loss: 0.039812
# Epoch: 692 Train loss: 0.0057071 Validation loss: 0.039815
# Epoch: 693 Train loss: 0.0057057 Validation loss: 0.039819
# Epoch: 694 Train loss: 0.0057044 Validation loss: 0.039822
# Epoch: 695 Train loss: 0.0057031 Validation loss: 0.039826
# Epoch: 696 Train loss: 0.0057018 Validation loss: 0.039829
# Epoch: 697 Train loss: 0.0057005 Validation loss: 0.039832
# Epoch: 698 Train loss: 0.0056992 Validation loss: 0.039835
# Epoch: 699 Train loss: 0.0056979 Validation loss: 0.039838
# Epoch: 700 Train loss: 0.0056966 Validation loss: 0.039843
# Epoch: 701 Train loss: 0.0056954 Validation loss: 0.039846
# Epoch: 702 Train loss: 0.0056941 Validation loss: 0.039849
# Epoch: 703 Train loss: 0.0056928 Validation loss: 0.039854
# Epoch: 704 Train loss: 0.0056915 Validation loss: 0.039857
# Epoch: 705 Train loss: 0.0056903 Validation loss: 0.039862
# Epoch: 706 Train loss: 0.005689 Validation loss: 0.039865
# Epoch: 707 Train loss: 0.0056878 Validation loss: 0.039868
# Epoch: 708 Train loss: 0.0056865 Validation loss: 0.039872
# Epoch: 709 Train loss: 0.0056853 Validation loss: 0.039878
# Epoch: 710 Train loss: 0.005684 Validation loss: 0.03988
# Epoch: 711 Train loss: 0.0056828 Validation loss: 0.039885
# Epoch: 712 Train loss: 0.0056815 Validation loss: 0.039888
# Epoch: 713 Train loss: 0.0056803 Validation loss: 0.039893
# Epoch: 714 Train loss: 0.0056791 Validation loss: 0.039896
# Epoch: 715 Train loss: 0.0056779 Validation loss: 0.039901
# Epoch: 716 Train loss: 0.0056766 Validation loss: 0.039905
# Epoch: 717 Train loss: 0.0056754 Validation loss: 0.039909
# Epoch: 718 Train loss: 0.0056742 Validation loss: 0.039913
# Epoch: 719 Train loss: 0.005673 Validation loss: 0.039918
# Epoch: 720 Train loss: 0.0056718 Validation loss: 0.039922
# Epoch: 721 Train loss: 0.0056706 Validation loss: 0.039926
# Epoch: 722 Train loss: 0.0056694 Validation loss: 0.039931
# Epoch: 723 Train loss: 0.0056682 Validation loss: 0.039936
# Epoch: 724 Train loss: 0.005667 Validation loss: 0.03994
# Epoch: 725 Train loss: 0.0056658 Validation loss: 0.039945
# Epoch: 726 Train loss: 0.0056647 Validation loss: 0.039949
# Epoch: 727 Train loss: 0.0056635 Validation loss: 0.039954
# Epoch: 728 Train loss: 0.0056623 Validation loss: 0.039958
# Epoch: 729 Train loss: 0.0056611 Validation loss: 0.039964
# Epoch: 730 Train loss: 0.00566 Validation loss: 0.039968
# Epoch: 731 Train loss: 0.0056588 Validation loss: 0.039973
# Epoch: 732 Train loss: 0.0056577 Validation loss: 0.039979
# Epoch: 733 Train loss: 0.0056565 Validation loss: 0.039983
# Epoch: 734 Train loss: 0.0056554 Validation loss: 0.039988
# Epoch: 735 Train loss: 0.0056542 Validation loss: 0.039994
# Epoch: 736 Train loss: 0.0056531 Validation loss: 0.039999
# Epoch: 737 Train loss: 0.0056519 Validation loss: 0.040005
# Epoch: 738 Train loss: 0.0056508 Validation loss: 0.040009
# Epoch: 739 Train loss: 0.0056497 Validation loss: 0.040015
# Epoch: 740 Train loss: 0.0056485 Validation loss: 0.04002
# Epoch: 741 Train loss: 0.0056474 Validation loss: 0.040026
# Epoch: 742 Train loss: 0.0056463 Validation loss: 0.040031
# Epoch: 743 Train loss: 0.0056452 Validation loss: 0.040037
# Epoch: 744 Train loss: 0.0056441 Validation loss: 0.040042
# Epoch: 745 Train loss: 0.005643 Validation loss: 0.040048
# Epoch: 746 Train loss: 0.0056419 Validation loss: 0.040053
# Epoch: 747 Train loss: 0.0056407 Validation loss: 0.040059
# Epoch: 748 Train loss: 0.0056396 Validation loss: 0.040064
# Epoch: 749 Train loss: 0.0056386 Validation loss: 0.04007
# Epoch: 750 Train loss: 0.0056375 Validation loss: 0.040075
# Epoch: 751 Train loss: 0.0056364 Validation loss: 0.040081
# Epoch: 752 Train loss: 0.0056353 Validation loss: 0.040087
# Epoch: 753 Train loss: 0.0056342 Validation loss: 0.040093
# Epoch: 754 Train loss: 0.0056331 Validation loss: 0.040098
# Epoch: 755 Train loss: 0.005632 Validation loss: 0.040104
# Epoch: 756 Train loss: 0.005631 Validation loss: 0.040111
# Epoch: 757 Train loss: 0.0056299 Validation loss: 0.040116
# Epoch: 758 Train loss: 0.0056288 Validation loss: 0.040121
# Epoch: 759 Train loss: 0.0056278 Validation loss: 0.040127
# Epoch: 760 Train loss: 0.0056267 Validation loss: 0.040133
# Epoch: 761 Train loss: 0.0056257 Validation loss: 0.040139
# Epoch: 762 Train loss: 0.0056246 Validation loss: 0.040145
# Epoch: 763 Train loss: 0.0056236 Validation loss: 0.04015
# Epoch: 764 Train loss: 0.0056225 Validation loss: 0.040157
# Epoch: 765 Train loss: 0.0056215 Validation loss: 0.040162
# Epoch: 766 Train loss: 0.0056204 Validation loss: 0.040168
# Epoch: 767 Train loss: 0.0056194 Validation loss: 0.040174
# Epoch: 768 Train loss: 0.0056184 Validation loss: 0.040181
# Epoch: 769 Train loss: 0.0056173 Validation loss: 0.040187
# Epoch: 770 Train loss: 0.0056163 Validation loss: 0.040194
# Epoch: 771 Train loss: 0.0056153 Validation loss: 0.0402
# Epoch: 772 Train loss: 0.0056143 Validation loss: 0.040207
# Epoch: 773 Train loss: 0.0056133 Validation loss: 0.040213
# Epoch: 774 Train loss: 0.0056123 Validation loss: 0.040219
# Epoch: 775 Train loss: 0.0056112 Validation loss: 0.040226
# Epoch: 776 Train loss: 0.0056102 Validation loss: 0.040232
# Epoch: 777 Train loss: 0.0056092 Validation loss: 0.040238
# Epoch: 778 Train loss: 0.0056082 Validation loss: 0.040245
# Epoch: 779 Train loss: 0.0056072 Validation loss: 0.040251
# Epoch: 780 Train loss: 0.0056062 Validation loss: 0.040258
# Epoch: 781 Train loss: 0.0056053 Validation loss: 0.040265
# Epoch: 782 Train loss: 0.0056043 Validation loss: 0.040272
# Epoch: 783 Train loss: 0.0056033 Validation loss: 0.040278
# Epoch: 784 Train loss: 0.0056023 Validation loss: 0.040285
# Epoch: 785 Train loss: 0.0056013 Validation loss: 0.040292
# Epoch: 786 Train loss: 0.0056003 Validation loss: 0.0403
# Epoch: 787 Train loss: 0.0055994 Validation loss: 0.040307
# Epoch: 788 Train loss: 0.0055984 Validation loss: 0.040313
# Epoch: 789 Train loss: 0.0055974 Validation loss: 0.04032
# Epoch: 790 Train loss: 0.0055965 Validation loss: 0.040327
# Epoch: 791 Train loss: 0.0055955 Validation loss: 0.040335
# Epoch: 792 Train loss: 0.0055945 Validation loss: 0.040342
# Epoch: 793 Train loss: 0.0055936 Validation loss: 0.040349
# Epoch: 794 Train loss: 0.0055926 Validation loss: 0.040356
# Epoch: 795 Train loss: 0.0055917 Validation loss: 0.040364
# Epoch: 796 Train loss: 0.0055907 Validation loss: 0.040371
# Epoch: 797 Train loss: 0.0055898 Validation loss: 0.040379
# Epoch: 798 Train loss: 0.0055888 Validation loss: 0.040385
# Epoch: 799 Train loss: 0.0055879 Validation loss: 0.040393
# Epoch: 800 Train loss: 0.005587 Validation loss: 0.0404
# Epoch: 801 Train loss: 0.005586 Validation loss: 0.040408
# Epoch: 802 Train loss: 0.0055851 Validation loss: 0.040414
# Epoch: 803 Train loss: 0.0055842 Validation loss: 0.040422
# Epoch: 804 Train loss: 0.0055832 Validation loss: 0.04043
# Epoch: 805 Train loss: 0.0055823 Validation loss: 0.040438
# Epoch: 806 Train loss: 0.0055814 Validation loss: 0.040445
# Epoch: 807 Train loss: 0.0055805 Validation loss: 0.040452
# Epoch: 808 Train loss: 0.0055796 Validation loss: 0.04046
# Epoch: 809 Train loss: 0.0055786 Validation loss: 0.040467
# Epoch: 810 Train loss: 0.0055777 Validation loss: 0.040475
# Epoch: 811 Train loss: 0.0055768 Validation loss: 0.040482
# Epoch: 812 Train loss: 0.0055759 Validation loss: 0.04049
# Epoch: 813 Train loss: 0.005575 Validation loss: 0.040497
# Epoch: 814 Train loss: 0.0055741 Validation loss: 0.040505
# Epoch: 815 Train loss: 0.0055732 Validation loss: 0.040513
# Epoch: 816 Train loss: 0.0055723 Validation loss: 0.04052
# Epoch: 817 Train loss: 0.0055714 Validation loss: 0.040528
# Epoch: 818 Train loss: 0.0055706 Validation loss: 0.040537
# Epoch: 819 Train loss: 0.0055697 Validation loss: 0.040544
# Epoch: 820 Train loss: 0.0055688 Validation loss: 0.040551
# Epoch: 821 Train loss: 0.0055679 Validation loss: 0.04056
# Epoch: 822 Train loss: 0.005567 Validation loss: 0.040568
# Epoch: 823 Train loss: 0.0055662 Validation loss: 0.040576
# Epoch: 824 Train loss: 0.0055653 Validation loss: 0.040584
# Epoch: 825 Train loss: 0.0055644 Validation loss: 0.040591
# Epoch: 826 Train loss: 0.0055635 Validation loss: 0.0406
# Epoch: 827 Train loss: 0.0055627 Validation loss: 0.040608
# Epoch: 828 Train loss: 0.0055618 Validation loss: 0.040616
# Epoch: 829 Train loss: 0.0055609 Validation loss: 0.040624
# Epoch: 830 Train loss: 0.0055601 Validation loss: 0.040632
# Epoch: 831 Train loss: 0.0055592 Validation loss: 0.040641
# Epoch: 832 Train loss: 0.0055584 Validation loss: 0.040649
# Epoch: 833 Train loss: 0.0055575 Validation loss: 0.040657
# Epoch: 834 Train loss: 0.0055567 Validation loss: 0.040665
# Epoch: 835 Train loss: 0.0055558 Validation loss: 0.040674
# Epoch: 836 Train loss: 0.005555 Validation loss: 0.040682
# Epoch: 837 Train loss: 0.0055541 Validation loss: 0.04069
# Epoch: 838 Train loss: 0.0055533 Validation loss: 0.040699
# Epoch: 839 Train loss: 0.0055524 Validation loss: 0.040708
# Epoch: 840 Train loss: 0.0055516 Validation loss: 0.040717
# Epoch: 841 Train loss: 0.0055508 Validation loss: 0.040725
# Epoch: 842 Train loss: 0.00555 Validation loss: 0.040734
# Epoch: 843 Train loss: 0.0055491 Validation loss: 0.040742
# Epoch: 844 Train loss: 0.0055483 Validation loss: 0.040751
# Epoch: 845 Train loss: 0.0055475 Validation loss: 0.040759
# Epoch: 846 Train loss: 0.0055467 Validation loss: 0.040769
# Epoch: 847 Train loss: 0.0055458 Validation loss: 0.040778
# Epoch: 848 Train loss: 0.005545 Validation loss: 0.040786
# Epoch: 849 Train loss: 0.0055442 Validation loss: 0.040795
# Epoch: 850 Train loss: 0.0055434 Validation loss: 0.040804
# Epoch: 851 Train loss: 0.0055426 Validation loss: 0.040813
# Epoch: 852 Train loss: 0.0055418 Validation loss: 0.040822
# Epoch: 853 Train loss: 0.005541 Validation loss: 0.040831
# Epoch: 854 Train loss: 0.0055402 Validation loss: 0.04084
# Epoch: 855 Train loss: 0.0055394 Validation loss: 0.040849
# Epoch: 856 Train loss: 0.0055386 Validation loss: 0.040858
# Epoch: 857 Train loss: 0.0055378 Validation loss: 0.040866
# Epoch: 858 Train loss: 0.005537 Validation loss: 0.040875
# Epoch: 859 Train loss: 0.0055362 Validation loss: 0.040884
# Epoch: 860 Train loss: 0.0055354 Validation loss: 0.040893
# Epoch: 861 Train loss: 0.0055346 Validation loss: 0.040902
# Epoch: 862 Train loss: 0.0055338 Validation loss: 0.040911
# Epoch: 863 Train loss: 0.005533 Validation loss: 0.040919
# Epoch: 864 Train loss: 0.0055323 Validation loss: 0.040929
# Epoch: 865 Train loss: 0.0055315 Validation loss: 0.040937
# Epoch: 866 Train loss: 0.0055307 Validation loss: 0.040946
# Epoch: 867 Train loss: 0.0055299 Validation loss: 0.040955
# Epoch: 868 Train loss: 0.0055292 Validation loss: 0.040964
# Epoch: 869 Train loss: 0.0055284 Validation loss: 0.040972
# Epoch: 870 Train loss: 0.0055276 Validation loss: 0.040982
# Epoch: 871 Train loss: 0.0055269 Validation loss: 0.040991
# Epoch: 872 Train loss: 0.0055261 Validation loss: 0.041
# Epoch: 873 Train loss: 0.0055253 Validation loss: 0.041009
# Epoch: 874 Train loss: 0.0055246 Validation loss: 0.041018
# Epoch: 875 Train loss: 0.0055238 Validation loss: 0.041028
# Epoch: 876 Train loss: 0.0055231 Validation loss: 0.041038
# Epoch: 877 Train loss: 0.0055223 Validation loss: 0.041046
# Epoch: 878 Train loss: 0.0055215 Validation loss: 0.041056
# Epoch: 879 Train loss: 0.0055208 Validation loss: 0.041065
# Epoch: 880 Train loss: 0.00552 Validation loss: 0.041074
# Epoch: 881 Train loss: 0.0055193 Validation loss: 0.041084
# Epoch: 882 Train loss: 0.0055186 Validation loss: 0.041093
# Epoch: 883 Train loss: 0.0055178 Validation loss: 0.041102
# Epoch: 884 Train loss: 0.0055171 Validation loss: 0.041112
# Epoch: 885 Train loss: 0.0055163 Validation loss: 0.041121
# Epoch: 886 Train loss: 0.0055156 Validation loss: 0.041131
# Epoch: 887 Train loss: 0.0055149 Validation loss: 0.041141
# Epoch: 888 Train loss: 0.0055141 Validation loss: 0.041151
# Epoch: 889 Train loss: 0.0055134 Validation loss: 0.041161
# Epoch: 890 Train loss: 0.0055127 Validation loss: 0.04117
# Epoch: 891 Train loss: 0.005512 Validation loss: 0.04118
# Epoch: 892 Train loss: 0.0055112 Validation loss: 0.041189
# Epoch: 893 Train loss: 0.0055105 Validation loss: 0.041199
# Epoch: 894 Train loss: 0.0055098 Validation loss: 0.041209
# Epoch: 895 Train loss: 0.0055091 Validation loss: 0.041219
# Epoch: 896 Train loss: 0.0055083 Validation loss: 0.041229
# Epoch: 897 Train loss: 0.0055076 Validation loss: 0.041239
# Epoch: 898 Train loss: 0.0055069 Validation loss: 0.041249
# Epoch: 899 Train loss: 0.0055062 Validation loss: 0.041258
# Epoch: 900 Train loss: 0.0055055 Validation loss: 0.041268
# Epoch: 901 Train loss: 0.0055048 Validation loss: 0.041278
# Epoch: 902 Train loss: 0.0055041 Validation loss: 0.041289
# Epoch: 903 Train loss: 0.0055033 Validation loss: 0.041299
# Epoch: 904 Train loss: 0.0055027 Validation loss: 0.041309
# Epoch: 905 Train loss: 0.005502 Validation loss: 0.041319
# Epoch: 906 Train loss: 0.0055013 Validation loss: 0.041329
# Epoch: 907 Train loss: 0.0055006 Validation loss: 0.041338
# Epoch: 908 Train loss: 0.0054999 Validation loss: 0.04135
# Epoch: 909 Train loss: 0.0054992 Validation loss: 0.041359
# Epoch: 910 Train loss: 0.0054985 Validation loss: 0.041369
# Epoch: 911 Train loss: 0.0054978 Validation loss: 0.04138
# Epoch: 912 Train loss: 0.0054971 Validation loss: 0.04139
# Epoch: 913 Train loss: 0.0054964 Validation loss: 0.0414
# Epoch: 914 Train loss: 0.0054957 Validation loss: 0.04141
# Epoch: 915 Train loss: 0.005495 Validation loss: 0.041421
# Epoch: 916 Train loss: 0.0054944 Validation loss: 0.041431
# Epoch: 917 Train loss: 0.0054937 Validation loss: 0.041442
# Epoch: 918 Train loss: 0.005493 Validation loss: 0.041452
# Epoch: 919 Train loss: 0.0054923 Validation loss: 0.041462
# Epoch: 920 Train loss: 0.0054916 Validation loss: 0.041473
# Epoch: 921 Train loss: 0.005491 Validation loss: 0.041483
# Epoch: 922 Train loss: 0.0054903 Validation loss: 0.041494
# Epoch: 923 Train loss: 0.0054896 Validation loss: 0.041504
# Epoch: 924 Train loss: 0.005489 Validation loss: 0.041515
# Epoch: 925 Train loss: 0.0054883 Validation loss: 0.041525
# Epoch: 926 Train loss: 0.0054876 Validation loss: 0.041536
# Epoch: 927 Train loss: 0.005487 Validation loss: 0.041547
# Epoch: 928 Train loss: 0.0054863 Validation loss: 0.041558
# Epoch: 929 Train loss: 0.0054856 Validation loss: 0.041568
# Epoch: 930 Train loss: 0.005485 Validation loss: 0.041579
# Epoch: 931 Train loss: 0.0054843 Validation loss: 0.04159
# Epoch: 932 Train loss: 0.0054837 Validation loss: 0.041601
# Epoch: 933 Train loss: 0.005483 Validation loss: 0.041612
# Epoch: 934 Train loss: 0.0054824 Validation loss: 0.041622
# Epoch: 935 Train loss: 0.0054817 Validation loss: 0.041633
# Epoch: 936 Train loss: 0.0054811 Validation loss: 0.041643
# Epoch: 937 Train loss: 0.0054804 Validation loss: 0.041655
# Epoch: 938 Train loss: 0.0054798 Validation loss: 0.041666
# Epoch: 939 Train loss: 0.0054791 Validation loss: 0.041676
# Epoch: 940 Train loss: 0.0054785 Validation loss: 0.041688
# Epoch: 941 Train loss: 0.0054778 Validation loss: 0.041699
# Epoch: 942 Train loss: 0.0054772 Validation loss: 0.041709
# Epoch: 943 Train loss: 0.0054766 Validation loss: 0.041721
# Epoch: 944 Train loss: 0.0054759 Validation loss: 0.041732
# Epoch: 945 Train loss: 0.0054753 Validation loss: 0.041743
# Epoch: 946 Train loss: 0.0054747 Validation loss: 0.041756
# Epoch: 947 Train loss: 0.005474 Validation loss: 0.041767
# Epoch: 948 Train loss: 0.0054734 Validation loss: 0.041778
# Epoch: 949 Train loss: 0.0054728 Validation loss: 0.041789
# Epoch: 950 Train loss: 0.0054721 Validation loss: 0.0418
# Epoch: 951 Train loss: 0.0054715 Validation loss: 0.041811
# Epoch: 952 Train loss: 0.0054709 Validation loss: 0.041822
# Epoch: 953 Train loss: 0.0054703 Validation loss: 0.041834
# Epoch: 954 Train loss: 0.0054697 Validation loss: 0.041845
# Epoch: 955 Train loss: 0.005469 Validation loss: 0.041856
# Epoch: 956 Train loss: 0.0054684 Validation loss: 0.041868
# Epoch: 957 Train loss: 0.0054678 Validation loss: 0.04188
# Epoch: 958 Train loss: 0.0054672 Validation loss: 0.041891
# Epoch: 959 Train loss: 0.0054666 Validation loss: 0.041903
# Epoch: 960 Train loss: 0.005466 Validation loss: 0.041915
# Epoch: 961 Train loss: 0.0054653 Validation loss: 0.041925
# Epoch: 962 Train loss: 0.0054647 Validation loss: 0.041937
# Epoch: 963 Train loss: 0.0054641 Validation loss: 0.04195
# Epoch: 964 Train loss: 0.0054635 Validation loss: 0.041961
# Epoch: 965 Train loss: 0.0054629 Validation loss: 0.041972
# Epoch: 966 Train loss: 0.0054623 Validation loss: 0.041984
# Epoch: 967 Train loss: 0.0054617 Validation loss: 0.041995
# Epoch: 968 Train loss: 0.0054611 Validation loss: 0.042007
# Epoch: 969 Train loss: 0.0054605 Validation loss: 0.042019
# Epoch: 970 Train loss: 0.0054599 Validation loss: 0.04203
# Epoch: 971 Train loss: 0.0054593 Validation loss: 0.042042
# Epoch: 972 Train loss: 0.0054587 Validation loss: 0.042054
# Epoch: 973 Train loss: 0.0054581 Validation loss: 0.042065
# Epoch: 974 Train loss: 0.0054575 Validation loss: 0.042077
# Epoch: 975 Train loss: 0.0054569 Validation loss: 0.042089
# Epoch: 976 Train loss: 0.0054563 Validation loss: 0.042101
# Epoch: 977 Train loss: 0.0054557 Validation loss: 0.042113
# Epoch: 978 Train loss: 0.0054552 Validation loss: 0.042125
# Epoch: 979 Train loss: 0.0054546 Validation loss: 0.042136
# Epoch: 980 Train loss: 0.005454 Validation loss: 0.042149
# Epoch: 981 Train loss: 0.0054534 Validation loss: 0.042161
# Epoch: 982 Train loss: 0.0054528 Validation loss: 0.042172
# Epoch: 983 Train loss: 0.0054522 Validation loss: 0.042185
# Epoch: 984 Train loss: 0.0054517 Validation loss: 0.042196
# Epoch: 985 Train loss: 0.0054511 Validation loss: 0.042208
# Epoch: 986 Train loss: 0.0054505 Validation loss: 0.04222
# Epoch: 987 Train loss: 0.0054499 Validation loss: 0.042232
# Epoch: 988 Train loss: 0.0054493 Validation loss: 0.042244
# Epoch: 989 Train loss: 0.0054488 Validation loss: 0.042257
# Epoch: 990 Train loss: 0.0054482 Validation loss: 0.042268
# Epoch: 991 Train loss: 0.0054476 Validation loss: 0.042281
# Epoch: 992 Train loss: 0.0054471 Validation loss: 0.042293
# Epoch: 993 Train loss: 0.0054465 Validation loss: 0.042305
# Epoch: 994 Train loss: 0.0054459 Validation loss: 0.042318
# Epoch: 995 Train loss: 0.0054454 Validation loss: 0.04233
# Epoch: 996 Train loss: 0.0054448 Validation loss: 0.042342
# Epoch: 997 Train loss: 0.0054442 Validation loss: 0.042355
# Epoch: 998 Train loss: 0.0054437 Validation loss: 0.042367
# Epoch: 999 Train loss: 0.0054431 Validation loss: 0.04238

# %% [markdown]
# Predicting with this model shows overfitting. For recognizing overfitting a comparison of the validation and training loss is very useful. If the training loss decreases during training while the validation loss consistently increases, the model you are training is probably overfitting. Plotting the models prediction and the target also shows that there is a significant discrepancy between the target and the prediction of the model.

# %%
y_pred = big_mdl(x)
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Target", "Prediction", "Training samples"])
plt.show()

# %% [markdown]
# In order to implement a regularization we need to modify the loss function. Since the loss function in this exercise is computed during the training step, we define a new training step with a regularization.

# %%
def regularized_train_step(model, optimizer, x, y, lmbd):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model(x)
        loss_val = tf.reduce_mean(tf.square(y-y_pred))
        regul_val = tf.reduce_sum([tf.reduce_sum(tf.square(w)) for w in model.trainable_variables])
        total_loss = tf.add(loss_val, lmbd*regul_val)
    grads = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# We can now set the strength of the regularization and retrain the big model with a regularization. We create another instance of the big model in order to compare the big model with and without regularization.

# %%
lmbd = 0.005

big_reg_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    train_loss += regularized_train_step(big_reg_mdl, big_opt, x_t, y_t, lmbd)
    train_iters += 1
    if (train_iters >= int(N_train_samples/batch_size)):
        for x_v, y_v in validation_ds:
            y_pred = big_reg_mdl(x_v)
            validation_loss = tf.reduce_mean(tf.square(y_v-y_pred))
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        train_reg = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 2.9865 Validation loss: 0.10045
# Epoch: 1 Train loss: 0.2963 Validation loss: 0.001251
# Epoch: 2 Train loss: 0.28036 Validation loss: 0.0049973
# Epoch: 3 Train loss: 0.26583 Validation loss: 0.033527
# Epoch: 4 Train loss: 0.24012 Validation loss: 0.078491
# Epoch: 5 Train loss: 0.20881 Validation loss: 0.050072
# Epoch: 6 Train loss: 0.20064 Validation loss: 0.042813
# Epoch: 7 Train loss: 0.19399 Validation loss: 0.03692
# Epoch: 8 Train loss: 0.18442 Validation loss: 0.03025
# Epoch: 9 Train loss: 0.17381 Validation loss: 0.029976
# Epoch: 10 Train loss: 0.16568 Validation loss: 0.034017
# Epoch: 11 Train loss: 0.15936 Validation loss: 0.037688
# Epoch: 12 Train loss: 0.15385 Validation loss: 0.040416
# Epoch: 13 Train loss: 0.14883 Validation loss: 0.045964
# Epoch: 14 Train loss: 0.14582 Validation loss: 0.083741
# Epoch: 15 Train loss: 0.18083 Validation loss: 0.21552
# Epoch: 16 Train loss: 0.18485 Validation loss: 0.09019
# Epoch: 17 Train loss: 0.14273 Validation loss: 0.0701
# Epoch: 18 Train loss: 0.1338 Validation loss: 0.073203
# Epoch: 19 Train loss: 0.12927 Validation loss: 0.076947
# Epoch: 20 Train loss: 0.1253 Validation loss: 0.078331
# Epoch: 21 Train loss: 0.12134 Validation loss: 0.077777
# Epoch: 22 Train loss: 0.11747 Validation loss: 0.076257
# Epoch: 23 Train loss: 0.11389 Validation loss: 0.074535
# Epoch: 24 Train loss: 0.11067 Validation loss: 0.073131
# Epoch: 25 Train loss: 0.10782 Validation loss: 0.072396
# Epoch: 26 Train loss: 0.10528 Validation loss: 0.0725
# Epoch: 27 Train loss: 0.10295 Validation loss: 0.073352
# Epoch: 28 Train loss: 0.10077 Validation loss: 0.074658
# Epoch: 29 Train loss: 0.098706 Validation loss: 0.07607
# Epoch: 30 Train loss: 0.09675 Validation loss: 0.077324
# Epoch: 31 Train loss: 0.094895 Validation loss: 0.078295
# Epoch: 32 Train loss: 0.093137 Validation loss: 0.078962
# Epoch: 33 Train loss: 0.091474 Validation loss: 0.079351
# Epoch: 34 Train loss: 0.089902 Validation loss: 0.07951
# Epoch: 35 Train loss: 0.088418 Validation loss: 0.07949
# Epoch: 36 Train loss: 0.087019 Validation loss: 0.079335
# Epoch: 37 Train loss: 0.0857 Validation loss: 0.07909
# Epoch: 38 Train loss: 0.084457 Validation loss: 0.078791
# Epoch: 39 Train loss: 0.083287 Validation loss: 0.078463
# Epoch: 40 Train loss: 0.082185 Validation loss: 0.078131
# Epoch: 41 Train loss: 0.081148 Validation loss: 0.07781
# Epoch: 42 Train loss: 0.08017 Validation loss: 0.077513
# Epoch: 43 Train loss: 0.07925 Validation loss: 0.077251
# Epoch: 44 Train loss: 0.078382 Validation loss: 0.077026
# Epoch: 45 Train loss: 0.077564 Validation loss: 0.076844
# Epoch: 46 Train loss: 0.076791 Validation loss: 0.076705
# Epoch: 47 Train loss: 0.076062 Validation loss: 0.076613
# Epoch: 48 Train loss: 0.075373 Validation loss: 0.076567
# Epoch: 49 Train loss: 0.074722 Validation loss: 0.076566
# Epoch: 50 Train loss: 0.074105 Validation loss: 0.076609
# Epoch: 51 Train loss: 0.07352 Validation loss: 0.076694
# Epoch: 52 Train loss: 0.072966 Validation loss: 0.076818
# Epoch: 53 Train loss: 0.07244 Validation loss: 0.076981
# Epoch: 54 Train loss: 0.07194 Validation loss: 0.077179
# Epoch: 55 Train loss: 0.071465 Validation loss: 0.077408
# Epoch: 56 Train loss: 0.071012 Validation loss: 0.077665
# Epoch: 57 Train loss: 0.07058 Validation loss: 0.077947
# Epoch: 58 Train loss: 0.070168 Validation loss: 0.078249
# Epoch: 59 Train loss: 0.069774 Validation loss: 0.078566
# Epoch: 60 Train loss: 0.069397 Validation loss: 0.078895
# Epoch: 61 Train loss: 0.069035 Validation loss: 0.079228
# Epoch: 62 Train loss: 0.068689 Validation loss: 0.079561
# Epoch: 63 Train loss: 0.068356 Validation loss: 0.079887
# Epoch: 64 Train loss: 0.068035 Validation loss: 0.080199
# Epoch: 65 Train loss: 0.067727 Validation loss: 0.080492
# Epoch: 66 Train loss: 0.06743 Validation loss: 0.080757
# Epoch: 67 Train loss: 0.067143 Validation loss: 0.080986
# Epoch: 68 Train loss: 0.066866 Validation loss: 0.081172
# Epoch: 69 Train loss: 0.066598 Validation loss: 0.081306
# Epoch: 70 Train loss: 0.066338 Validation loss: 0.081384
# Epoch: 71 Train loss: 0.066087 Validation loss: 0.081393
# Epoch: 72 Train loss: 0.065844 Validation loss: 0.08133
# Epoch: 73 Train loss: 0.065608 Validation loss: 0.081188
# Epoch: 74 Train loss: 0.065379 Validation loss: 0.080962
# Epoch: 75 Train loss: 0.065157 Validation loss: 0.080648
# Epoch: 76 Train loss: 0.064942 Validation loss: 0.080245
# Epoch: 77 Train loss: 0.064733 Validation loss: 0.079751
# Epoch: 78 Train loss: 0.06453 Validation loss: 0.079169
# Epoch: 79 Train loss: 0.064334 Validation loss: 0.078502
# Epoch: 80 Train loss: 0.064143 Validation loss: 0.077755
# Epoch: 81 Train loss: 0.063958 Validation loss: 0.076934
# Epoch: 82 Train loss: 0.063778 Validation loss: 0.076051
# Epoch: 83 Train loss: 0.063604 Validation loss: 0.075113
# Epoch: 84 Train loss: 0.063434 Validation loss: 0.07413
# Epoch: 85 Train loss: 0.063268 Validation loss: 0.073113
# Epoch: 86 Train loss: 0.063106 Validation loss: 0.072074
# Epoch: 87 Train loss: 0.062947 Validation loss: 0.071022
# Epoch: 88 Train loss: 0.062791 Validation loss: 0.069967
# Epoch: 89 Train loss: 0.062637 Validation loss: 0.068917
# Epoch: 90 Train loss: 0.062485 Validation loss: 0.06788
# Epoch: 91 Train loss: 0.062334 Validation loss: 0.066863
# Epoch: 92 Train loss: 0.062183 Validation loss: 0.065871
# Epoch: 93 Train loss: 0.062032 Validation loss: 0.06491
# Epoch: 94 Train loss: 0.061879 Validation loss: 0.063982
# Epoch: 95 Train loss: 0.061723 Validation loss: 0.063091
# Epoch: 96 Train loss: 0.061564 Validation loss: 0.062238
# Epoch: 97 Train loss: 0.061399 Validation loss: 0.061427
# Epoch: 98 Train loss: 0.061227 Validation loss: 0.060657
# Epoch: 99 Train loss: 0.061046 Validation loss: 0.059931
# Epoch: 100 Train loss: 0.06085 Validation loss: 0.059252
# Epoch: 101 Train loss: 0.060637 Validation loss: 0.058622
# Epoch: 102 Train loss: 0.060398 Validation loss: 0.058047
# Epoch: 103 Train loss: 0.060122 Validation loss: 0.057536
# Epoch: 104 Train loss: 0.059792 Validation loss: 0.057105
# Epoch: 105 Train loss: 0.059377 Validation loss: 0.056786
# Epoch: 106 Train loss: 0.058821 Validation loss: 0.05664
# Epoch: 107 Train loss: 0.058018 Validation loss: 0.056784
# Epoch: 108 Train loss: 0.056771 Validation loss: 0.057387
# Epoch: 109 Train loss: 0.054868 Validation loss: 0.058157
# Epoch: 110 Train loss: 0.052599 Validation loss: 0.057224
# Epoch: 111 Train loss: 0.050678 Validation loss: 0.05406
# Epoch: 112 Train loss: 0.049196 Validation loss: 0.050694
# Epoch: 113 Train loss: 0.047969 Validation loss: 0.048157
# Epoch: 114 Train loss: 0.046884 Validation loss: 0.046503
# Epoch: 115 Train loss: 0.04589 Validation loss: 0.045524
# Epoch: 116 Train loss: 0.04496 Validation loss: 0.045011
# Epoch: 117 Train loss: 0.044083 Validation loss: 0.044798
# Epoch: 118 Train loss: 0.04325 Validation loss: 0.044773
# Epoch: 119 Train loss: 0.042457 Validation loss: 0.044859
# Epoch: 120 Train loss: 0.041699 Validation loss: 0.045008
# Epoch: 121 Train loss: 0.040973 Validation loss: 0.045188
# Epoch: 122 Train loss: 0.040278 Validation loss: 0.045381
# Epoch: 123 Train loss: 0.039611 Validation loss: 0.045575
# Epoch: 124 Train loss: 0.038969 Validation loss: 0.045764
# Epoch: 125 Train loss: 0.038352 Validation loss: 0.045947
# Epoch: 126 Train loss: 0.037758 Validation loss: 0.04612
# Epoch: 127 Train loss: 0.037185 Validation loss: 0.046283
# Epoch: 128 Train loss: 0.036633 Validation loss: 0.046439
# Epoch: 129 Train loss: 0.036101 Validation loss: 0.046585
# Epoch: 130 Train loss: 0.035587 Validation loss: 0.046726
# Epoch: 131 Train loss: 0.03509 Validation loss: 0.046858
# Epoch: 132 Train loss: 0.034611 Validation loss: 0.046985
# Epoch: 133 Train loss: 0.034148 Validation loss: 0.047105
# Epoch: 134 Train loss: 0.0337 Validation loss: 0.047221
# Epoch: 135 Train loss: 0.033268 Validation loss: 0.047331
# Epoch: 136 Train loss: 0.03285 Validation loss: 0.047437
# Epoch: 137 Train loss: 0.032445 Validation loss: 0.047539
# Epoch: 138 Train loss: 0.032054 Validation loss: 0.047635
# Epoch: 139 Train loss: 0.031676 Validation loss: 0.047727
# Epoch: 140 Train loss: 0.03131 Validation loss: 0.047815
# Epoch: 141 Train loss: 0.030957 Validation loss: 0.047898
# Epoch: 142 Train loss: 0.030614 Validation loss: 0.047975
# Epoch: 143 Train loss: 0.030283 Validation loss: 0.048047
# Epoch: 144 Train loss: 0.029963 Validation loss: 0.048113
# Epoch: 145 Train loss: 0.029653 Validation loss: 0.048174
# Epoch: 146 Train loss: 0.029352 Validation loss: 0.048229
# Epoch: 147 Train loss: 0.029062 Validation loss: 0.048275
# Epoch: 148 Train loss: 0.02878 Validation loss: 0.048315
# Epoch: 149 Train loss: 0.028508 Validation loss: 0.048346
# Epoch: 150 Train loss: 0.028244 Validation loss: 0.048368
# Epoch: 151 Train loss: 0.027988 Validation loss: 0.048382
# Epoch: 152 Train loss: 0.027741 Validation loss: 0.048384
# Epoch: 153 Train loss: 0.027501 Validation loss: 0.048377
# Epoch: 154 Train loss: 0.027269 Validation loss: 0.048357
# Epoch: 155 Train loss: 0.027044 Validation loss: 0.048326
# Epoch: 156 Train loss: 0.026826 Validation loss: 0.048282
# Epoch: 157 Train loss: 0.026615 Validation loss: 0.048224
# Epoch: 158 Train loss: 0.026411 Validation loss: 0.048154
# Epoch: 159 Train loss: 0.026213 Validation loss: 0.048069
# Epoch: 160 Train loss: 0.026021 Validation loss: 0.047971
# Epoch: 161 Train loss: 0.025836 Validation loss: 0.04786
# Epoch: 162 Train loss: 0.025656 Validation loss: 0.047736
# Epoch: 163 Train loss: 0.025482 Validation loss: 0.0476
# Epoch: 164 Train loss: 0.025314 Validation loss: 0.047451
# Epoch: 165 Train loss: 0.025151 Validation loss: 0.047291
# Epoch: 166 Train loss: 0.024994 Validation loss: 0.047123
# Epoch: 167 Train loss: 0.024842 Validation loss: 0.046946
# Epoch: 168 Train loss: 0.024695 Validation loss: 0.046763
# Epoch: 169 Train loss: 0.024553 Validation loss: 0.046575
# Epoch: 170 Train loss: 0.024415 Validation loss: 0.046382
# Epoch: 171 Train loss: 0.024283 Validation loss: 0.046188
# Epoch: 172 Train loss: 0.024155 Validation loss: 0.045994
# Epoch: 173 Train loss: 0.024032 Validation loss: 0.045801
# Epoch: 174 Train loss: 0.023912 Validation loss: 0.045609
# Epoch: 175 Train loss: 0.023797 Validation loss: 0.045422
# Epoch: 176 Train loss: 0.023686 Validation loss: 0.04524
# Epoch: 177 Train loss: 0.023579 Validation loss: 0.045063
# Epoch: 178 Train loss: 0.023476 Validation loss: 0.044893
# Epoch: 179 Train loss: 0.023377 Validation loss: 0.044731
# Epoch: 180 Train loss: 0.023281 Validation loss: 0.044576
# Epoch: 181 Train loss: 0.023188 Validation loss: 0.044429
# Epoch: 182 Train loss: 0.023099 Validation loss: 0.044291
# Epoch: 183 Train loss: 0.023012 Validation loss: 0.044161
# Epoch: 184 Train loss: 0.022929 Validation loss: 0.044039
# Epoch: 185 Train loss: 0.022849 Validation loss: 0.043926
# Epoch: 186 Train loss: 0.022772 Validation loss: 0.043821
# Epoch: 187 Train loss: 0.022697 Validation loss: 0.043723
# Epoch: 188 Train loss: 0.022625 Validation loss: 0.043633
# Epoch: 189 Train loss: 0.022555 Validation loss: 0.04355
# Epoch: 190 Train loss: 0.022488 Validation loss: 0.043474
# Epoch: 191 Train loss: 0.022423 Validation loss: 0.043405
# Epoch: 192 Train loss: 0.022361 Validation loss: 0.04334
# Epoch: 193 Train loss: 0.0223 Validation loss: 0.043281
# Epoch: 194 Train loss: 0.022242 Validation loss: 0.043228
# Epoch: 195 Train loss: 0.022186 Validation loss: 0.043179
# Epoch: 196 Train loss: 0.022132 Validation loss: 0.043133
# Epoch: 197 Train loss: 0.022079 Validation loss: 0.043092
# Epoch: 198 Train loss: 0.022028 Validation loss: 0.043053
# Epoch: 199 Train loss: 0.02198 Validation loss: 0.043017
# Epoch: 200 Train loss: 0.021932 Validation loss: 0.042984
# Epoch: 201 Train loss: 0.021887 Validation loss: 0.042952
# Epoch: 202 Train loss: 0.021843 Validation loss: 0.042923
# Epoch: 203 Train loss: 0.0218 Validation loss: 0.042893
# Epoch: 204 Train loss: 0.021759 Validation loss: 0.042866
# Epoch: 205 Train loss: 0.02172 Validation loss: 0.042838
# Epoch: 206 Train loss: 0.021681 Validation loss: 0.042811
# Epoch: 207 Train loss: 0.021644 Validation loss: 0.042785
# Epoch: 208 Train loss: 0.021609 Validation loss: 0.042758
# Epoch: 209 Train loss: 0.021574 Validation loss: 0.042731
# Epoch: 210 Train loss: 0.021541 Validation loss: 0.042703
# Epoch: 211 Train loss: 0.021509 Validation loss: 0.042675
# Epoch: 212 Train loss: 0.021478 Validation loss: 0.042645
# Epoch: 213 Train loss: 0.021448 Validation loss: 0.042613
# Epoch: 214 Train loss: 0.021419 Validation loss: 0.042582
# Epoch: 215 Train loss: 0.021391 Validation loss: 0.042548
# Epoch: 216 Train loss: 0.021364 Validation loss: 0.042512
# Epoch: 217 Train loss: 0.021338 Validation loss: 0.042473
# Epoch: 218 Train loss: 0.021313 Validation loss: 0.042433
# Epoch: 219 Train loss: 0.021289 Validation loss: 0.042388
# Epoch: 220 Train loss: 0.021266 Validation loss: 0.04233
# Epoch: 221 Train loss: 0.021244 Validation loss: 0.042223
# Epoch: 222 Train loss: 0.021222 Validation loss: 0.041875
# Epoch: 223 Train loss: 0.021207 Validation loss: 0.040223
# Epoch: 224 Train loss: 0.021356 Validation loss: 0.031063
# Epoch: 225 Train loss: 0.027204 Validation loss: 0.0020798
# Epoch: 226 Train loss: 0.047982 Validation loss: 0.0071199
# Epoch: 227 Train loss: 0.026412 Validation loss: 0.031832
# Epoch: 228 Train loss: 0.021716 Validation loss: 0.03938
# Epoch: 229 Train loss: 0.021266 Validation loss: 0.040812
# Epoch: 230 Train loss: 0.021168 Validation loss: 0.040653
# Epoch: 231 Train loss: 0.021128 Validation loss: 0.039905
# Epoch: 232 Train loss: 0.021115 Validation loss: 0.03858
# Epoch: 233 Train loss: 0.021149 Validation loss: 0.036058
# Epoch: 234 Train loss: 0.021379 Validation loss: 0.030595
# Epoch: 235 Train loss: 0.022693 Validation loss: 0.019254
# Epoch: 236 Train loss: 0.028279 Validation loss: 0.0077216
# Epoch: 237 Train loss: 0.032145 Validation loss: 0.012202
# Epoch: 238 Train loss: 0.026005 Validation loss: 0.023625
# Epoch: 239 Train loss: 0.022689 Validation loss: 0.029786
# Epoch: 240 Train loss: 0.021805 Validation loss: 0.031624
# Epoch: 241 Train loss: 0.021611 Validation loss: 0.031022
# Epoch: 242 Train loss: 0.021746 Validation loss: 0.028449
# Epoch: 243 Train loss: 0.022346 Validation loss: 0.023668
# Epoch: 244 Train loss: 0.02393 Validation loss: 0.017383
# Epoch: 245 Train loss: 0.026442 Validation loss: 0.013684
# Epoch: 246 Train loss: 0.027086 Validation loss: 0.015941
# Epoch: 247 Train loss: 0.025133 Validation loss: 0.020851
# Epoch: 248 Train loss: 0.023416 Validation loss: 0.024343
# Epoch: 249 Train loss: 0.022643 Validation loss: 0.025591
# Epoch: 250 Train loss: 0.022469 Validation loss: 0.024987
# Epoch: 251 Train loss: 0.022722 Validation loss: 0.022936
# Epoch: 252 Train loss: 0.023415 Validation loss: 0.020025
# Epoch: 253 Train loss: 0.02445 Validation loss: 0.017527
# Epoch: 254 Train loss: 0.025222 Validation loss: 0.016942
# Epoch: 255 Train loss: 0.025054 Validation loss: 0.018375
# Epoch: 256 Train loss: 0.024253 Validation loss: 0.02045
# Epoch: 257 Train loss: 0.023524 Validation loss: 0.021923
# Epoch: 258 Train loss: 0.023138 Validation loss: 0.022367
# Epoch: 259 Train loss: 0.02308 Validation loss: 0.021852
# Epoch: 260 Train loss: 0.023299 Validation loss: 0.020674
# Epoch: 261 Train loss: 0.023715 Validation loss: 0.019319
# Epoch: 262 Train loss: 0.024161 Validation loss: 0.018389
# Epoch: 263 Train loss: 0.024387 Validation loss: 0.018286
# Epoch: 264 Train loss: 0.02427 Validation loss: 0.018909
# Epoch: 265 Train loss: 0.023936 Validation loss: 0.019775
# Epoch: 266 Train loss: 0.023601 Validation loss: 0.020428
# Epoch: 267 Train loss: 0.023394 Validation loss: 0.020644
# Epoch: 268 Train loss: 0.023348 Validation loss: 0.020414
# Epoch: 269 Train loss: 0.023441 Validation loss: 0.019879
# Epoch: 270 Train loss: 0.023622 Validation loss: 0.019264
# Epoch: 271 Train loss: 0.023809 Validation loss: 0.018808
# Epoch: 272 Train loss: 0.023914 Validation loss: 0.018666
# Epoch: 273 Train loss: 0.023891 Validation loss: 0.018831
# Epoch: 274 Train loss: 0.023766 Validation loss: 0.019161
# Epoch: 275 Train loss: 0.023607 Validation loss: 0.019477
# Epoch: 276 Train loss: 0.023478 Validation loss: 0.019648
# Epoch: 277 Train loss: 0.023411 Validation loss: 0.019628
# Epoch: 278 Train loss: 0.023412 Validation loss: 0.019444
# Epoch: 279 Train loss: 0.023464 Validation loss: 0.019171
# Epoch: 280 Train loss: 0.023538 Validation loss: 0.018905
# Epoch: 281 Train loss: 0.023599 Validation loss: 0.018727
# Epoch: 282 Train loss: 0.023621 Validation loss: 0.018673
# Epoch: 283 Train loss: 0.023596 Validation loss: 0.018728
# Epoch: 284 Train loss: 0.023535 Validation loss: 0.018842
# Epoch: 285 Train loss: 0.023462 Validation loss: 0.018951
# Epoch: 286 Train loss: 0.023399 Validation loss: 0.019006
# Epoch: 287 Train loss: 0.02336 Validation loss: 0.018988
# Epoch: 288 Train loss: 0.023348 Validation loss: 0.018901
# Epoch: 289 Train loss: 0.023358 Validation loss: 0.01877
# Epoch: 290 Train loss: 0.02338 Validation loss: 0.018631
# Epoch: 291 Train loss: 0.023402 Validation loss: 0.018512
# Epoch: 292 Train loss: 0.023413 Validation loss: 0.018435
# Epoch: 293 Train loss: 0.023408 Validation loss: 0.018401
# Epoch: 294 Train loss: 0.023387 Validation loss: 0.018401
# Epoch: 295 Train loss: 0.023357 Validation loss: 0.018413
# Epoch: 296 Train loss: 0.023325 Validation loss: 0.018418
# Epoch: 297 Train loss: 0.023298 Validation loss: 0.018402
# Epoch: 298 Train loss: 0.02328 Validation loss: 0.018357
# Epoch: 299 Train loss: 0.023273 Validation loss: 0.018285
# Epoch: 300 Train loss: 0.023275 Validation loss: 0.018194
# Epoch: 301 Train loss: 0.023282 Validation loss: 0.018095
# Epoch: 302 Train loss: 0.023292 Validation loss: 0.017998
# Epoch: 303 Train loss: 0.023299 Validation loss: 0.017914
# Epoch: 304 Train loss: 0.023301 Validation loss: 0.017843
# Epoch: 305 Train loss: 0.023299 Validation loss: 0.017786
# Epoch: 306 Train loss: 0.023292 Validation loss: 0.017736
# Epoch: 307 Train loss: 0.023283 Validation loss: 0.017687
# Epoch: 308 Train loss: 0.023275 Validation loss: 0.017632
# Epoch: 309 Train loss: 0.02327 Validation loss: 0.017567
# Epoch: 310 Train loss: 0.02327 Validation loss: 0.017489
# Epoch: 311 Train loss: 0.023274 Validation loss: 0.0174
# Epoch: 312 Train loss: 0.023282 Validation loss: 0.017304
# Epoch: 313 Train loss: 0.023293 Validation loss: 0.017202
# Epoch: 314 Train loss: 0.023305 Validation loss: 0.0171
# Epoch: 315 Train loss: 0.023317 Validation loss: 0.017001
# Epoch: 316 Train loss: 0.023328 Validation loss: 0.016906
# Epoch: 317 Train loss: 0.023338 Validation loss: 0.016815
# Epoch: 318 Train loss: 0.023346 Validation loss: 0.016729
# Epoch: 319 Train loss: 0.023353 Validation loss: 0.016643
# Epoch: 320 Train loss: 0.02336 Validation loss: 0.016558
# Epoch: 321 Train loss: 0.023368 Validation loss: 0.016471
# Epoch: 322 Train loss: 0.023377 Validation loss: 0.016379
# Epoch: 323 Train loss: 0.023388 Validation loss: 0.016284
# Epoch: 324 Train loss: 0.0234 Validation loss: 0.016186
# Epoch: 325 Train loss: 0.023414 Validation loss: 0.016086
# Epoch: 326 Train loss: 0.023429 Validation loss: 0.015985
# Epoch: 327 Train loss: 0.023444 Validation loss: 0.015887
# Epoch: 328 Train loss: 0.023459 Validation loss: 0.015792
# Epoch: 329 Train loss: 0.023472 Validation loss: 0.015701
# Epoch: 330 Train loss: 0.023483 Validation loss: 0.015614
# Epoch: 331 Train loss: 0.023494 Validation loss: 0.015531
# Epoch: 332 Train loss: 0.023503 Validation loss: 0.015451
# Epoch: 333 Train loss: 0.023511 Validation loss: 0.015374
# Epoch: 334 Train loss: 0.023519 Validation loss: 0.015297
# Epoch: 335 Train loss: 0.023526 Validation loss: 0.015223
# Epoch: 336 Train loss: 0.023534 Validation loss: 0.015149
# Epoch: 337 Train loss: 0.02354 Validation loss: 0.015077
# Epoch: 338 Train loss: 0.023547 Validation loss: 0.015006
# Epoch: 339 Train loss: 0.023553 Validation loss: 0.014937
# Epoch: 340 Train loss: 0.023558 Validation loss: 0.014872
# Epoch: 341 Train loss: 0.023562 Validation loss: 0.01481
# Epoch: 342 Train loss: 0.023565 Validation loss: 0.014752
# Epoch: 343 Train loss: 0.023566 Validation loss: 0.014699
# Epoch: 344 Train loss: 0.023565 Validation loss: 0.014649
# Epoch: 345 Train loss: 0.023563 Validation loss: 0.014603
# Epoch: 346 Train loss: 0.02356 Validation loss: 0.01456
# Epoch: 347 Train loss: 0.023555 Validation loss: 0.01452
# Epoch: 348 Train loss: 0.023549 Validation loss: 0.014482
# Epoch: 349 Train loss: 0.023542 Validation loss: 0.014447
# Epoch: 350 Train loss: 0.023535 Validation loss: 0.014413
# Epoch: 351 Train loss: 0.023526 Validation loss: 0.014382
# Epoch: 352 Train loss: 0.023517 Validation loss: 0.014352
# Epoch: 353 Train loss: 0.023507 Validation loss: 0.014325
# Epoch: 354 Train loss: 0.023496 Validation loss: 0.0143
# Epoch: 355 Train loss: 0.023483 Validation loss: 0.014277
# Epoch: 356 Train loss: 0.02347 Validation loss: 0.014257
# Epoch: 357 Train loss: 0.023455 Validation loss: 0.014239
# Epoch: 358 Train loss: 0.02344 Validation loss: 0.014224
# Epoch: 359 Train loss: 0.023423 Validation loss: 0.014211
# Epoch: 360 Train loss: 0.023406 Validation loss: 0.0142
# Epoch: 361 Train loss: 0.023387 Validation loss: 0.01419
# Epoch: 362 Train loss: 0.023368 Validation loss: 0.014182
# Epoch: 363 Train loss: 0.023348 Validation loss: 0.014175
# Epoch: 364 Train loss: 0.023328 Validation loss: 0.014168
# Epoch: 365 Train loss: 0.023308 Validation loss: 0.014163
# Epoch: 366 Train loss: 0.023287 Validation loss: 0.014158
# Epoch: 367 Train loss: 0.023265 Validation loss: 0.014153
# Epoch: 368 Train loss: 0.023244 Validation loss: 0.014149
# Epoch: 369 Train loss: 0.023222 Validation loss: 0.014146
# Epoch: 370 Train loss: 0.023199 Validation loss: 0.014143
# Epoch: 371 Train loss: 0.023177 Validation loss: 0.014141
# Epoch: 372 Train loss: 0.023154 Validation loss: 0.014139
# Epoch: 373 Train loss: 0.023132 Validation loss: 0.014137
# Epoch: 374 Train loss: 0.023109 Validation loss: 0.014135
# Epoch: 375 Train loss: 0.023086 Validation loss: 0.014134
# Epoch: 376 Train loss: 0.023063 Validation loss: 0.014132
# Epoch: 377 Train loss: 0.02304 Validation loss: 0.014131
# Epoch: 378 Train loss: 0.023018 Validation loss: 0.014129
# Epoch: 379 Train loss: 0.022996 Validation loss: 0.014127
# Epoch: 380 Train loss: 0.022974 Validation loss: 0.014125
# Epoch: 381 Train loss: 0.022952 Validation loss: 0.014122
# Epoch: 382 Train loss: 0.022931 Validation loss: 0.014118
# Epoch: 383 Train loss: 0.022911 Validation loss: 0.014114
# Epoch: 384 Train loss: 0.022891 Validation loss: 0.01411
# Epoch: 385 Train loss: 0.022872 Validation loss: 0.014105
# Epoch: 386 Train loss: 0.022854 Validation loss: 0.014099
# Epoch: 387 Train loss: 0.022836 Validation loss: 0.014092
# Epoch: 388 Train loss: 0.022819 Validation loss: 0.014085
# Epoch: 389 Train loss: 0.022803 Validation loss: 0.014077
# Epoch: 390 Train loss: 0.022788 Validation loss: 0.014068
# Epoch: 391 Train loss: 0.022774 Validation loss: 0.014059
# Epoch: 392 Train loss: 0.022761 Validation loss: 0.01405
# Epoch: 393 Train loss: 0.022749 Validation loss: 0.01404
# Epoch: 394 Train loss: 0.022738 Validation loss: 0.01403
# Epoch: 395 Train loss: 0.022728 Validation loss: 0.01402
# Epoch: 396 Train loss: 0.02272 Validation loss: 0.01401
# Epoch: 397 Train loss: 0.022712 Validation loss: 0.013999
# Epoch: 398 Train loss: 0.022706 Validation loss: 0.013989
# Epoch: 399 Train loss: 0.022701 Validation loss: 0.01398
# Epoch: 400 Train loss: 0.022697 Validation loss: 0.013971
# Epoch: 401 Train loss: 0.022695 Validation loss: 0.013962
# Epoch: 402 Train loss: 0.022694 Validation loss: 0.013953
# Epoch: 403 Train loss: 0.022694 Validation loss: 0.013946
# Epoch: 404 Train loss: 0.022695 Validation loss: 0.013939
# Epoch: 405 Train loss: 0.022698 Validation loss: 0.013933
# Epoch: 406 Train loss: 0.022703 Validation loss: 0.013928
# Epoch: 407 Train loss: 0.022708 Validation loss: 0.013923
# Epoch: 408 Train loss: 0.022715 Validation loss: 0.01392
# Epoch: 409 Train loss: 0.022724 Validation loss: 0.013918
# Epoch: 410 Train loss: 0.022733 Validation loss: 0.013916
# Epoch: 411 Train loss: 0.022744 Validation loss: 0.013916
# Epoch: 412 Train loss: 0.022756 Validation loss: 0.013917
# Epoch: 413 Train loss: 0.02277 Validation loss: 0.013918
# Epoch: 414 Train loss: 0.022785 Validation loss: 0.013921
# Epoch: 415 Train loss: 0.0228 Validation loss: 0.013925
# Epoch: 416 Train loss: 0.022817 Validation loss: 0.01393
# Epoch: 417 Train loss: 0.022835 Validation loss: 0.013937
# Epoch: 418 Train loss: 0.022854 Validation loss: 0.013945
# Epoch: 419 Train loss: 0.022874 Validation loss: 0.013954
# Epoch: 420 Train loss: 0.022894 Validation loss: 0.013965
# Epoch: 421 Train loss: 0.022916 Validation loss: 0.013978
# Epoch: 422 Train loss: 0.022938 Validation loss: 0.013994
# Epoch: 423 Train loss: 0.022961 Validation loss: 0.014011
# Epoch: 424 Train loss: 0.022985 Validation loss: 0.014032
# Epoch: 425 Train loss: 0.023009 Validation loss: 0.014055
# Epoch: 426 Train loss: 0.023034 Validation loss: 0.014082
# Epoch: 427 Train loss: 0.023059 Validation loss: 0.014112
# Epoch: 428 Train loss: 0.023085 Validation loss: 0.014146
# Epoch: 429 Train loss: 0.023112 Validation loss: 0.014185
# Epoch: 430 Train loss: 0.023139 Validation loss: 0.014227
# Epoch: 431 Train loss: 0.023166 Validation loss: 0.014274
# Epoch: 432 Train loss: 0.023194 Validation loss: 0.014325
# Epoch: 433 Train loss: 0.023222 Validation loss: 0.014382
# Epoch: 434 Train loss: 0.023251 Validation loss: 0.014443
# Epoch: 435 Train loss: 0.02328 Validation loss: 0.014509
# Epoch: 436 Train loss: 0.023309 Validation loss: 0.014579
# Epoch: 437 Train loss: 0.023338 Validation loss: 0.014655
# Epoch: 438 Train loss: 0.023368 Validation loss: 0.014735
# Epoch: 439 Train loss: 0.023397 Validation loss: 0.01482
# Epoch: 440 Train loss: 0.023427 Validation loss: 0.01491
# Epoch: 441 Train loss: 0.023457 Validation loss: 0.015004
# Epoch: 442 Train loss: 0.023487 Validation loss: 0.015102
# Epoch: 443 Train loss: 0.023518 Validation loss: 0.015204
# Epoch: 444 Train loss: 0.023548 Validation loss: 0.01531
# Epoch: 445 Train loss: 0.023578 Validation loss: 0.01542
# Epoch: 446 Train loss: 0.023608 Validation loss: 0.015533
# Epoch: 447 Train loss: 0.023638 Validation loss: 0.015649
# Epoch: 448 Train loss: 0.023669 Validation loss: 0.015769
# Epoch: 449 Train loss: 0.023699 Validation loss: 0.015892
# Epoch: 450 Train loss: 0.023729 Validation loss: 0.016017
# Epoch: 451 Train loss: 0.023759 Validation loss: 0.016146
# Epoch: 452 Train loss: 0.023788 Validation loss: 0.016277
# Epoch: 453 Train loss: 0.023818 Validation loss: 0.01641
# Epoch: 454 Train loss: 0.023847 Validation loss: 0.016546
# Epoch: 455 Train loss: 0.023877 Validation loss: 0.016683
# Epoch: 456 Train loss: 0.023906 Validation loss: 0.016823
# Epoch: 457 Train loss: 0.023935 Validation loss: 0.016965
# Epoch: 458 Train loss: 0.023964 Validation loss: 0.017108
# Epoch: 459 Train loss: 0.023992 Validation loss: 0.017253
# Epoch: 460 Train loss: 0.024021 Validation loss: 0.0174
# Epoch: 461 Train loss: 0.024049 Validation loss: 0.017549
# Epoch: 462 Train loss: 0.024077 Validation loss: 0.017698
# Epoch: 463 Train loss: 0.024105 Validation loss: 0.017849
# Epoch: 464 Train loss: 0.024132 Validation loss: 0.018002
# Epoch: 465 Train loss: 0.02416 Validation loss: 0.018156
# Epoch: 466 Train loss: 0.024187 Validation loss: 0.018312
# Epoch: 467 Train loss: 0.024214 Validation loss: 0.018468
# Epoch: 468 Train loss: 0.024241 Validation loss: 0.018626
# Epoch: 469 Train loss: 0.024267 Validation loss: 0.018784
# Epoch: 470 Train loss: 0.024294 Validation loss: 0.018944
# Epoch: 471 Train loss: 0.02432 Validation loss: 0.019105
# Epoch: 472 Train loss: 0.024346 Validation loss: 0.019267
# Epoch: 473 Train loss: 0.024371 Validation loss: 0.01943
# Epoch: 474 Train loss: 0.024397 Validation loss: 0.019594
# Epoch: 475 Train loss: 0.024422 Validation loss: 0.019758
# Epoch: 476 Train loss: 0.024447 Validation loss: 0.019924
# Epoch: 477 Train loss: 0.024472 Validation loss: 0.020091
# Epoch: 478 Train loss: 0.024497 Validation loss: 0.020259
# Epoch: 479 Train loss: 0.024521 Validation loss: 0.020427
# Epoch: 480 Train loss: 0.024545 Validation loss: 0.020596
# Epoch: 481 Train loss: 0.024569 Validation loss: 0.020766
# Epoch: 482 Train loss: 0.024593 Validation loss: 0.020937
# Epoch: 483 Train loss: 0.024617 Validation loss: 0.021109
# Epoch: 484 Train loss: 0.02464 Validation loss: 0.021282
# Epoch: 485 Train loss: 0.024663 Validation loss: 0.021455
# Epoch: 486 Train loss: 0.024686 Validation loss: 0.021629
# Epoch: 487 Train loss: 0.024709 Validation loss: 0.021804
# Epoch: 488 Train loss: 0.024731 Validation loss: 0.02198
# Epoch: 489 Train loss: 0.024754 Validation loss: 0.022156
# Epoch: 490 Train loss: 0.024776 Validation loss: 0.022333
# Epoch: 491 Train loss: 0.024798 Validation loss: 0.02251
# Epoch: 492 Train loss: 0.02482 Validation loss: 0.022689
# Epoch: 493 Train loss: 0.024841 Validation loss: 0.022867
# Epoch: 494 Train loss: 0.024863 Validation loss: 0.023047
# Epoch: 495 Train loss: 0.024884 Validation loss: 0.023227
# Epoch: 496 Train loss: 0.024905 Validation loss: 0.023408
# Epoch: 497 Train loss: 0.024926 Validation loss: 0.023589
# Epoch: 498 Train loss: 0.024946 Validation loss: 0.023771
# Epoch: 499 Train loss: 0.024967 Validation loss: 0.023953
# Epoch: 500 Train loss: 0.024987 Validation loss: 0.024136
# Epoch: 501 Train loss: 0.025007 Validation loss: 0.024318
# Epoch: 502 Train loss: 0.025027 Validation loss: 0.024502
# Epoch: 503 Train loss: 0.025046 Validation loss: 0.024685
# Epoch: 504 Train loss: 0.025066 Validation loss: 0.02487
# Epoch: 505 Train loss: 0.025085 Validation loss: 0.025054
# Epoch: 506 Train loss: 0.025104 Validation loss: 0.025238
# Epoch: 507 Train loss: 0.025123 Validation loss: 0.025422
# Epoch: 508 Train loss: 0.025142 Validation loss: 0.025607
# Epoch: 509 Train loss: 0.02516 Validation loss: 0.025792
# Epoch: 510 Train loss: 0.025178 Validation loss: 0.025976
# Epoch: 511 Train loss: 0.025196 Validation loss: 0.02616
# Epoch: 512 Train loss: 0.025214 Validation loss: 0.026345
# Epoch: 513 Train loss: 0.025232 Validation loss: 0.026529
# Epoch: 514 Train loss: 0.02525 Validation loss: 0.026712
# Epoch: 515 Train loss: 0.025267 Validation loss: 0.026895
# Epoch: 516 Train loss: 0.025284 Validation loss: 0.027078
# Epoch: 517 Train loss: 0.025301 Validation loss: 0.02726
# Epoch: 518 Train loss: 0.025318 Validation loss: 0.027441
# Epoch: 519 Train loss: 0.025334 Validation loss: 0.027622
# Epoch: 520 Train loss: 0.025351 Validation loss: 0.027802
# Epoch: 521 Train loss: 0.025367 Validation loss: 0.027981
# Epoch: 522 Train loss: 0.025383 Validation loss: 0.028158
# Epoch: 523 Train loss: 0.025399 Validation loss: 0.028334
# Epoch: 524 Train loss: 0.025415 Validation loss: 0.028509
# Epoch: 525 Train loss: 0.02543 Validation loss: 0.028683
# Epoch: 526 Train loss: 0.025445 Validation loss: 0.028855
# Epoch: 527 Train loss: 0.02546 Validation loss: 0.029025
# Epoch: 528 Train loss: 0.025475 Validation loss: 0.029194
# Epoch: 529 Train loss: 0.02549 Validation loss: 0.02936
# Epoch: 530 Train loss: 0.025504 Validation loss: 0.029524
# Epoch: 531 Train loss: 0.025519 Validation loss: 0.029687
# Epoch: 532 Train loss: 0.025533 Validation loss: 0.029846
# Epoch: 533 Train loss: 0.025547 Validation loss: 0.030003
# Epoch: 534 Train loss: 0.02556 Validation loss: 0.030158
# Epoch: 535 Train loss: 0.025574 Validation loss: 0.03031
# Epoch: 536 Train loss: 0.025587 Validation loss: 0.030458
# Epoch: 537 Train loss: 0.0256 Validation loss: 0.030604
# Epoch: 538 Train loss: 0.025613 Validation loss: 0.030746
# Epoch: 539 Train loss: 0.025626 Validation loss: 0.030885
# Epoch: 540 Train loss: 0.025639 Validation loss: 0.03102
# Epoch: 541 Train loss: 0.025651 Validation loss: 0.031152
# Epoch: 542 Train loss: 0.025664 Validation loss: 0.031279
# Epoch: 543 Train loss: 0.025676 Validation loss: 0.031403
# Epoch: 544 Train loss: 0.025688 Validation loss: 0.031523
# Epoch: 545 Train loss: 0.0257 Validation loss: 0.031638
# Epoch: 546 Train loss: 0.025712 Validation loss: 0.031749
# Epoch: 547 Train loss: 0.025723 Validation loss: 0.031856
# Epoch: 548 Train loss: 0.025735 Validation loss: 0.031958
# Epoch: 549 Train loss: 0.025746 Validation loss: 0.032055
# Epoch: 550 Train loss: 0.025758 Validation loss: 0.032148
# Epoch: 551 Train loss: 0.025769 Validation loss: 0.032236
# Epoch: 552 Train loss: 0.02578 Validation loss: 0.032319
# Epoch: 553 Train loss: 0.025791 Validation loss: 0.032397
# Epoch: 554 Train loss: 0.025802 Validation loss: 0.03247
# Epoch: 555 Train loss: 0.025813 Validation loss: 0.032538
# Epoch: 556 Train loss: 0.025823 Validation loss: 0.032602
# Epoch: 557 Train loss: 0.025834 Validation loss: 0.03266
# Epoch: 558 Train loss: 0.025845 Validation loss: 0.032714
# Epoch: 559 Train loss: 0.025855 Validation loss: 0.032762
# Epoch: 560 Train loss: 0.025866 Validation loss: 0.032806
# Epoch: 561 Train loss: 0.025877 Validation loss: 0.032845
# Epoch: 562 Train loss: 0.025887 Validation loss: 0.032879
# Epoch: 563 Train loss: 0.025898 Validation loss: 0.032909
# Epoch: 564 Train loss: 0.025908 Validation loss: 0.032934
# Epoch: 565 Train loss: 0.025919 Validation loss: 0.032955
# Epoch: 566 Train loss: 0.02593 Validation loss: 0.032972
# Epoch: 567 Train loss: 0.02594 Validation loss: 0.032985
# Epoch: 568 Train loss: 0.025951 Validation loss: 0.032993
# Epoch: 569 Train loss: 0.025962 Validation loss: 0.032998
# Epoch: 570 Train loss: 0.025972 Validation loss: 0.033
# Epoch: 571 Train loss: 0.025983 Validation loss: 0.032998
# Epoch: 572 Train loss: 0.025994 Validation loss: 0.032993
# Epoch: 573 Train loss: 0.026005 Validation loss: 0.032984
# Epoch: 574 Train loss: 0.026016 Validation loss: 0.032973
# Epoch: 575 Train loss: 0.026027 Validation loss: 0.03296
# Epoch: 576 Train loss: 0.026038 Validation loss: 0.032944
# Epoch: 577 Train loss: 0.02605 Validation loss: 0.032925
# Epoch: 578 Train loss: 0.026061 Validation loss: 0.032905
# Epoch: 579 Train loss: 0.026072 Validation loss: 0.032883
# Epoch: 580 Train loss: 0.026084 Validation loss: 0.032859
# Epoch: 581 Train loss: 0.026095 Validation loss: 0.032834
# Epoch: 582 Train loss: 0.026107 Validation loss: 0.032807
# Epoch: 583 Train loss: 0.026118 Validation loss: 0.03278
# Epoch: 584 Train loss: 0.02613 Validation loss: 0.032751
# Epoch: 585 Train loss: 0.026142 Validation loss: 0.032722
# Epoch: 586 Train loss: 0.026154 Validation loss: 0.032692
# Epoch: 587 Train loss: 0.026166 Validation loss: 0.032661
# Epoch: 588 Train loss: 0.026178 Validation loss: 0.03263
# Epoch: 589 Train loss: 0.02619 Validation loss: 0.032599
# Epoch: 590 Train loss: 0.026202 Validation loss: 0.032569
# Epoch: 591 Train loss: 0.026214 Validation loss: 0.032537
# Epoch: 592 Train loss: 0.026226 Validation loss: 0.032507
# Epoch: 593 Train loss: 0.026238 Validation loss: 0.032476
# Epoch: 594 Train loss: 0.02625 Validation loss: 0.032446
# Epoch: 595 Train loss: 0.026262 Validation loss: 0.032416
# Epoch: 596 Train loss: 0.026275 Validation loss: 0.032386
# Epoch: 597 Train loss: 0.026287 Validation loss: 0.032357
# Epoch: 598 Train loss: 0.026299 Validation loss: 0.032329
# Epoch: 599 Train loss: 0.026311 Validation loss: 0.032301
# Epoch: 600 Train loss: 0.026323 Validation loss: 0.032274
# Epoch: 601 Train loss: 0.026336 Validation loss: 0.032248
# Epoch: 602 Train loss: 0.026348 Validation loss: 0.032222
# Epoch: 603 Train loss: 0.02636 Validation loss: 0.032197
# Epoch: 604 Train loss: 0.026372 Validation loss: 0.032172
# Epoch: 605 Train loss: 0.026384 Validation loss: 0.032149
# Epoch: 606 Train loss: 0.026396 Validation loss: 0.032126
# Epoch: 607 Train loss: 0.026408 Validation loss: 0.032103
# Epoch: 608 Train loss: 0.02642 Validation loss: 0.032082
# Epoch: 609 Train loss: 0.026432 Validation loss: 0.032061
# Epoch: 610 Train loss: 0.026444 Validation loss: 0.032041
# Epoch: 611 Train loss: 0.026456 Validation loss: 0.032021
# Epoch: 612 Train loss: 0.026468 Validation loss: 0.032002
# Epoch: 613 Train loss: 0.02648 Validation loss: 0.031984
# Epoch: 614 Train loss: 0.026492 Validation loss: 0.031965
# Epoch: 615 Train loss: 0.026504 Validation loss: 0.031948
# Epoch: 616 Train loss: 0.026515 Validation loss: 0.031931
# Epoch: 617 Train loss: 0.026527 Validation loss: 0.031915
# Epoch: 618 Train loss: 0.026539 Validation loss: 0.031899
# Epoch: 619 Train loss: 0.02655 Validation loss: 0.031883
# Epoch: 620 Train loss: 0.026562 Validation loss: 0.031869
# Epoch: 621 Train loss: 0.026574 Validation loss: 0.031854
# Epoch: 622 Train loss: 0.026585 Validation loss: 0.031839
# Epoch: 623 Train loss: 0.026597 Validation loss: 0.031825
# Epoch: 624 Train loss: 0.026608 Validation loss: 0.031812
# Epoch: 625 Train loss: 0.02662 Validation loss: 0.031798
# Epoch: 626 Train loss: 0.026631 Validation loss: 0.031785
# Epoch: 627 Train loss: 0.026642 Validation loss: 0.031771
# Epoch: 628 Train loss: 0.026654 Validation loss: 0.031759
# Epoch: 629 Train loss: 0.026665 Validation loss: 0.031746
# Epoch: 630 Train loss: 0.026676 Validation loss: 0.031733
# Epoch: 631 Train loss: 0.026688 Validation loss: 0.031721
# Epoch: 632 Train loss: 0.026699 Validation loss: 0.031708
# Epoch: 633 Train loss: 0.02671 Validation loss: 0.031696
# Epoch: 634 Train loss: 0.026721 Validation loss: 0.031683
# Epoch: 635 Train loss: 0.026733 Validation loss: 0.031671
# Epoch: 636 Train loss: 0.026744 Validation loss: 0.031659
# Epoch: 637 Train loss: 0.026755 Validation loss: 0.031647
# Epoch: 638 Train loss: 0.026766 Validation loss: 0.031634
# Epoch: 639 Train loss: 0.026777 Validation loss: 0.031622
# Epoch: 640 Train loss: 0.026788 Validation loss: 0.031609
# Epoch: 641 Train loss: 0.0268 Validation loss: 0.031597
# Epoch: 642 Train loss: 0.026811 Validation loss: 0.031585
# Epoch: 643 Train loss: 0.026822 Validation loss: 0.031572
# Epoch: 644 Train loss: 0.026833 Validation loss: 0.031559
# Epoch: 645 Train loss: 0.026844 Validation loss: 0.031547
# Epoch: 646 Train loss: 0.026855 Validation loss: 0.031534
# Epoch: 647 Train loss: 0.026866 Validation loss: 0.031521
# Epoch: 648 Train loss: 0.026877 Validation loss: 0.031508
# Epoch: 649 Train loss: 0.026888 Validation loss: 0.031495
# Epoch: 650 Train loss: 0.026899 Validation loss: 0.031482
# Epoch: 651 Train loss: 0.026911 Validation loss: 0.031469
# Epoch: 652 Train loss: 0.026922 Validation loss: 0.031456
# Epoch: 653 Train loss: 0.026933 Validation loss: 0.031442
# Epoch: 654 Train loss: 0.026944 Validation loss: 0.031429
# Epoch: 655 Train loss: 0.026955 Validation loss: 0.031415
# Epoch: 656 Train loss: 0.026966 Validation loss: 0.031402
# Epoch: 657 Train loss: 0.026977 Validation loss: 0.031387
# Epoch: 658 Train loss: 0.026988 Validation loss: 0.031374
# Epoch: 659 Train loss: 0.026999 Validation loss: 0.03136
# Epoch: 660 Train loss: 0.02701 Validation loss: 0.031346
# Epoch: 661 Train loss: 0.027021 Validation loss: 0.031332
# Epoch: 662 Train loss: 0.027033 Validation loss: 0.031317
# Epoch: 663 Train loss: 0.027044 Validation loss: 0.031303
# Epoch: 664 Train loss: 0.027055 Validation loss: 0.031288
# Epoch: 665 Train loss: 0.027066 Validation loss: 0.031274
# Epoch: 666 Train loss: 0.027077 Validation loss: 0.03126
# Epoch: 667 Train loss: 0.027088 Validation loss: 0.031245
# Epoch: 668 Train loss: 0.027099 Validation loss: 0.03123
# Epoch: 669 Train loss: 0.02711 Validation loss: 0.031216
# Epoch: 670 Train loss: 0.027121 Validation loss: 0.031201
# Epoch: 671 Train loss: 0.027133 Validation loss: 0.031186
# Epoch: 672 Train loss: 0.027144 Validation loss: 0.031171
# Epoch: 673 Train loss: 0.027155 Validation loss: 0.031157
# Epoch: 674 Train loss: 0.027166 Validation loss: 0.031142
# Epoch: 675 Train loss: 0.027177 Validation loss: 0.031127
# Epoch: 676 Train loss: 0.027188 Validation loss: 0.031112
# Epoch: 677 Train loss: 0.027199 Validation loss: 0.031097
# Epoch: 678 Train loss: 0.027211 Validation loss: 0.031082
# Epoch: 679 Train loss: 0.027222 Validation loss: 0.031067
# Epoch: 680 Train loss: 0.027233 Validation loss: 0.031052
# Epoch: 681 Train loss: 0.027244 Validation loss: 0.031037
# Epoch: 682 Train loss: 0.027255 Validation loss: 0.031022
# Epoch: 683 Train loss: 0.027266 Validation loss: 0.031007
# Epoch: 684 Train loss: 0.027277 Validation loss: 0.030992
# Epoch: 685 Train loss: 0.027289 Validation loss: 0.030977
# Epoch: 686 Train loss: 0.0273 Validation loss: 0.030962
# Epoch: 687 Train loss: 0.027311 Validation loss: 0.030947
# Epoch: 688 Train loss: 0.027322 Validation loss: 0.030932
# Epoch: 689 Train loss: 0.027333 Validation loss: 0.030917
# Epoch: 690 Train loss: 0.027345 Validation loss: 0.030902
# Epoch: 691 Train loss: 0.027356 Validation loss: 0.030887
# Epoch: 692 Train loss: 0.027367 Validation loss: 0.030872
# Epoch: 693 Train loss: 0.027378 Validation loss: 0.030858
# Epoch: 694 Train loss: 0.027389 Validation loss: 0.030843
# Epoch: 695 Train loss: 0.0274 Validation loss: 0.030828
# Epoch: 696 Train loss: 0.027412 Validation loss: 0.030813
# Epoch: 697 Train loss: 0.027423 Validation loss: 0.030798
# Epoch: 698 Train loss: 0.027434 Validation loss: 0.030783
# Epoch: 699 Train loss: 0.027445 Validation loss: 0.030769
# Epoch: 700 Train loss: 0.027456 Validation loss: 0.030754
# Epoch: 701 Train loss: 0.027468 Validation loss: 0.030739
# Epoch: 702 Train loss: 0.027479 Validation loss: 0.030724
# Epoch: 703 Train loss: 0.02749 Validation loss: 0.030709
# Epoch: 704 Train loss: 0.027501 Validation loss: 0.030695
# Epoch: 705 Train loss: 0.027512 Validation loss: 0.03068
# Epoch: 706 Train loss: 0.027523 Validation loss: 0.030665
# Epoch: 707 Train loss: 0.027535 Validation loss: 0.03065
# Epoch: 708 Train loss: 0.027546 Validation loss: 0.030635
# Epoch: 709 Train loss: 0.027557 Validation loss: 0.03062
# Epoch: 710 Train loss: 0.027568 Validation loss: 0.030606
# Epoch: 711 Train loss: 0.027579 Validation loss: 0.030591
# Epoch: 712 Train loss: 0.02759 Validation loss: 0.030576
# Epoch: 713 Train loss: 0.027602 Validation loss: 0.030561
# Epoch: 714 Train loss: 0.027613 Validation loss: 0.030546
# Epoch: 715 Train loss: 0.027624 Validation loss: 0.030531
# Epoch: 716 Train loss: 0.027635 Validation loss: 0.030516
# Epoch: 717 Train loss: 0.027646 Validation loss: 0.030501
# Epoch: 718 Train loss: 0.027658 Validation loss: 0.030486
# Epoch: 719 Train loss: 0.027669 Validation loss: 0.030471
# Epoch: 720 Train loss: 0.02768 Validation loss: 0.030456
# Epoch: 721 Train loss: 0.027691 Validation loss: 0.030441
# Epoch: 722 Train loss: 0.027702 Validation loss: 0.030425
# Epoch: 723 Train loss: 0.027713 Validation loss: 0.03041
# Epoch: 724 Train loss: 0.027725 Validation loss: 0.030394
# Epoch: 725 Train loss: 0.027736 Validation loss: 0.030379
# Epoch: 726 Train loss: 0.027747 Validation loss: 0.030364
# Epoch: 727 Train loss: 0.027758 Validation loss: 0.030348
# Epoch: 728 Train loss: 0.027769 Validation loss: 0.030332
# Epoch: 729 Train loss: 0.02778 Validation loss: 0.030316
# Epoch: 730 Train loss: 0.027792 Validation loss: 0.0303
# Epoch: 731 Train loss: 0.027803 Validation loss: 0.030284
# Epoch: 732 Train loss: 0.027814 Validation loss: 0.030268
# Epoch: 733 Train loss: 0.027825 Validation loss: 0.030251
# Epoch: 734 Train loss: 0.027836 Validation loss: 0.030235
# Epoch: 735 Train loss: 0.027848 Validation loss: 0.030219
# Epoch: 736 Train loss: 0.027859 Validation loss: 0.030202
# Epoch: 737 Train loss: 0.02787 Validation loss: 0.030185
# Epoch: 738 Train loss: 0.027881 Validation loss: 0.030168
# Epoch: 739 Train loss: 0.027892 Validation loss: 0.030151
# Epoch: 740 Train loss: 0.027904 Validation loss: 0.030133
# Epoch: 741 Train loss: 0.027915 Validation loss: 0.030116
# Epoch: 742 Train loss: 0.027926 Validation loss: 0.030098
# Epoch: 743 Train loss: 0.027937 Validation loss: 0.030081
# Epoch: 744 Train loss: 0.027948 Validation loss: 0.030063
# Epoch: 745 Train loss: 0.02796 Validation loss: 0.030045
# Epoch: 746 Train loss: 0.027971 Validation loss: 0.030026
# Epoch: 747 Train loss: 0.027982 Validation loss: 0.030007
# Epoch: 748 Train loss: 0.027993 Validation loss: 0.029989
# Epoch: 749 Train loss: 0.028005 Validation loss: 0.02997
# Epoch: 750 Train loss: 0.028016 Validation loss: 0.029951
# Epoch: 751 Train loss: 0.028027 Validation loss: 0.029931
# Epoch: 752 Train loss: 0.028038 Validation loss: 0.029912
# Epoch: 753 Train loss: 0.02805 Validation loss: 0.029892
# Epoch: 754 Train loss: 0.028061 Validation loss: 0.029872
# Epoch: 755 Train loss: 0.028072 Validation loss: 0.029852
# Epoch: 756 Train loss: 0.028083 Validation loss: 0.029831
# Epoch: 757 Train loss: 0.028095 Validation loss: 0.02981
# Epoch: 758 Train loss: 0.028106 Validation loss: 0.029789
# Epoch: 759 Train loss: 0.028117 Validation loss: 0.029768
# Epoch: 760 Train loss: 0.028129 Validation loss: 0.029747
# Epoch: 761 Train loss: 0.02814 Validation loss: 0.029725
# Epoch: 762 Train loss: 0.028152 Validation loss: 0.029703
# Epoch: 763 Train loss: 0.028163 Validation loss: 0.02968
# Epoch: 764 Train loss: 0.028174 Validation loss: 0.029658
# Epoch: 765 Train loss: 0.028186 Validation loss: 0.029635
# Epoch: 766 Train loss: 0.028197 Validation loss: 0.029612
# Epoch: 767 Train loss: 0.028209 Validation loss: 0.029589
# Epoch: 768 Train loss: 0.02822 Validation loss: 0.029565
# Epoch: 769 Train loss: 0.028232 Validation loss: 0.029541
# Epoch: 770 Train loss: 0.028243 Validation loss: 0.029517
# Epoch: 771 Train loss: 0.028254 Validation loss: 0.029492
# Epoch: 772 Train loss: 0.028266 Validation loss: 0.029467
# Epoch: 773 Train loss: 0.028278 Validation loss: 0.029442
# Epoch: 774 Train loss: 0.028289 Validation loss: 0.029417
# Epoch: 775 Train loss: 0.028301 Validation loss: 0.029391
# Epoch: 776 Train loss: 0.028312 Validation loss: 0.029365
# Epoch: 777 Train loss: 0.028324 Validation loss: 0.029338
# Epoch: 778 Train loss: 0.028335 Validation loss: 0.029312
# Epoch: 779 Train loss: 0.028347 Validation loss: 0.029285
# Epoch: 780 Train loss: 0.028359 Validation loss: 0.029257
# Epoch: 781 Train loss: 0.02837 Validation loss: 0.02923
# Epoch: 782 Train loss: 0.028382 Validation loss: 0.029202
# Epoch: 783 Train loss: 0.028394 Validation loss: 0.029173
# Epoch: 784 Train loss: 0.028406 Validation loss: 0.029145
# Epoch: 785 Train loss: 0.028417 Validation loss: 0.029116
# Epoch: 786 Train loss: 0.028429 Validation loss: 0.029087
# Epoch: 787 Train loss: 0.028441 Validation loss: 0.029057
# Epoch: 788 Train loss: 0.028453 Validation loss: 0.029027
# Epoch: 789 Train loss: 0.028465 Validation loss: 0.028996
# Epoch: 790 Train loss: 0.028477 Validation loss: 0.028966
# Epoch: 791 Train loss: 0.028489 Validation loss: 0.028935
# Epoch: 792 Train loss: 0.028501 Validation loss: 0.028904
# Epoch: 793 Train loss: 0.028513 Validation loss: 0.028872
# Epoch: 794 Train loss: 0.028525 Validation loss: 0.02884
# Epoch: 795 Train loss: 0.028537 Validation loss: 0.028808
# Epoch: 796 Train loss: 0.028549 Validation loss: 0.028775
# Epoch: 797 Train loss: 0.028561 Validation loss: 0.028742
# Epoch: 798 Train loss: 0.028573 Validation loss: 0.028709
# Epoch: 799 Train loss: 0.028585 Validation loss: 0.028675
# Epoch: 800 Train loss: 0.028597 Validation loss: 0.028641
# Epoch: 801 Train loss: 0.02861 Validation loss: 0.028607
# Epoch: 802 Train loss: 0.028622 Validation loss: 0.028572
# Epoch: 803 Train loss: 0.028634 Validation loss: 0.028537
# Epoch: 804 Train loss: 0.028647 Validation loss: 0.028501
# Epoch: 805 Train loss: 0.028659 Validation loss: 0.028466
# Epoch: 806 Train loss: 0.028671 Validation loss: 0.02843
# Epoch: 807 Train loss: 0.028684 Validation loss: 0.028394
# Epoch: 808 Train loss: 0.028696 Validation loss: 0.028357
# Epoch: 809 Train loss: 0.028709 Validation loss: 0.02832
# Epoch: 810 Train loss: 0.028721 Validation loss: 0.028282
# Epoch: 811 Train loss: 0.028734 Validation loss: 0.028245
# Epoch: 812 Train loss: 0.028747 Validation loss: 0.028207
# Epoch: 813 Train loss: 0.028759 Validation loss: 0.028168
# Epoch: 814 Train loss: 0.028772 Validation loss: 0.028129
# Epoch: 815 Train loss: 0.028785 Validation loss: 0.02809
# Epoch: 816 Train loss: 0.028797 Validation loss: 0.028051
# Epoch: 817 Train loss: 0.02881 Validation loss: 0.028011
# Epoch: 818 Train loss: 0.028823 Validation loss: 0.027971
# Epoch: 819 Train loss: 0.028836 Validation loss: 0.027931
# Epoch: 820 Train loss: 0.028849 Validation loss: 0.02789
# Epoch: 821 Train loss: 0.028862 Validation loss: 0.027849
# Epoch: 822 Train loss: 0.028875 Validation loss: 0.027808
# Epoch: 823 Train loss: 0.028888 Validation loss: 0.027766
# Epoch: 824 Train loss: 0.028901 Validation loss: 0.027725
# Epoch: 825 Train loss: 0.028914 Validation loss: 0.027682
# Epoch: 826 Train loss: 0.028927 Validation loss: 0.02764
# Epoch: 827 Train loss: 0.02894 Validation loss: 0.027597
# Epoch: 828 Train loss: 0.028953 Validation loss: 0.027553
# Epoch: 829 Train loss: 0.028966 Validation loss: 0.02751
# Epoch: 830 Train loss: 0.02898 Validation loss: 0.027466
# Epoch: 831 Train loss: 0.028993 Validation loss: 0.027422
# Epoch: 832 Train loss: 0.029006 Validation loss: 0.027378
# Epoch: 833 Train loss: 0.02902 Validation loss: 0.027333
# Epoch: 834 Train loss: 0.029033 Validation loss: 0.027288
# Epoch: 835 Train loss: 0.029047 Validation loss: 0.027243
# Epoch: 836 Train loss: 0.02906 Validation loss: 0.027197
# Epoch: 837 Train loss: 0.029074 Validation loss: 0.027151
# Epoch: 838 Train loss: 0.029087 Validation loss: 0.027105
# Epoch: 839 Train loss: 0.029101 Validation loss: 0.027059
# Epoch: 840 Train loss: 0.029114 Validation loss: 0.027013
# Epoch: 841 Train loss: 0.029128 Validation loss: 0.026966
# Epoch: 842 Train loss: 0.029142 Validation loss: 0.026918
# Epoch: 843 Train loss: 0.029155 Validation loss: 0.026871
# Epoch: 844 Train loss: 0.029169 Validation loss: 0.026824
# Epoch: 845 Train loss: 0.029183 Validation loss: 0.026776
# Epoch: 846 Train loss: 0.029197 Validation loss: 0.026727
# Epoch: 847 Train loss: 0.029211 Validation loss: 0.026679
# Epoch: 848 Train loss: 0.029225 Validation loss: 0.02663
# Epoch: 849 Train loss: 0.029239 Validation loss: 0.026581
# Epoch: 850 Train loss: 0.029253 Validation loss: 0.026532
# Epoch: 851 Train loss: 0.029267 Validation loss: 0.026483
# Epoch: 852 Train loss: 0.029281 Validation loss: 0.026433
# Epoch: 853 Train loss: 0.029295 Validation loss: 0.026383
# Epoch: 854 Train loss: 0.029309 Validation loss: 0.026333
# Epoch: 855 Train loss: 0.029323 Validation loss: 0.026283
# Epoch: 856 Train loss: 0.029337 Validation loss: 0.026232
# Epoch: 857 Train loss: 0.029351 Validation loss: 0.026182
# Epoch: 858 Train loss: 0.029365 Validation loss: 0.026131
# Epoch: 859 Train loss: 0.02938 Validation loss: 0.026079
# Epoch: 860 Train loss: 0.029394 Validation loss: 0.026028
# Epoch: 861 Train loss: 0.029408 Validation loss: 0.025976
# Epoch: 862 Train loss: 0.029423 Validation loss: 0.025925
# Epoch: 863 Train loss: 0.029437 Validation loss: 0.025873
# Epoch: 864 Train loss: 0.029451 Validation loss: 0.02582
# Epoch: 865 Train loss: 0.029466 Validation loss: 0.025768
# Epoch: 866 Train loss: 0.02948 Validation loss: 0.025716
# Epoch: 867 Train loss: 0.029495 Validation loss: 0.025663
# Epoch: 868 Train loss: 0.029509 Validation loss: 0.02561
# Epoch: 869 Train loss: 0.029524 Validation loss: 0.025557
# Epoch: 870 Train loss: 0.029538 Validation loss: 0.025504
# Epoch: 871 Train loss: 0.029553 Validation loss: 0.025451
# Epoch: 872 Train loss: 0.029568 Validation loss: 0.025397
# Epoch: 873 Train loss: 0.029582 Validation loss: 0.025344
# Epoch: 874 Train loss: 0.029597 Validation loss: 0.02529
# Epoch: 875 Train loss: 0.029612 Validation loss: 0.025236
# Epoch: 876 Train loss: 0.029626 Validation loss: 0.025182
# Epoch: 877 Train loss: 0.029641 Validation loss: 0.025128
# Epoch: 878 Train loss: 0.029656 Validation loss: 0.025073
# Epoch: 879 Train loss: 0.029671 Validation loss: 0.025019
# Epoch: 880 Train loss: 0.029686 Validation loss: 0.024964
# Epoch: 881 Train loss: 0.0297 Validation loss: 0.02491
# Epoch: 882 Train loss: 0.029715 Validation loss: 0.024855
# Epoch: 883 Train loss: 0.02973 Validation loss: 0.0248
# Epoch: 884 Train loss: 0.029745 Validation loss: 0.024745
# Epoch: 885 Train loss: 0.02976 Validation loss: 0.02469
# Epoch: 886 Train loss: 0.029775 Validation loss: 0.024635
# Epoch: 887 Train loss: 0.02979 Validation loss: 0.02458
# Epoch: 888 Train loss: 0.029805 Validation loss: 0.024524
# Epoch: 889 Train loss: 0.02982 Validation loss: 0.024469
# Epoch: 890 Train loss: 0.029835 Validation loss: 0.024413
# Epoch: 891 Train loss: 0.02985 Validation loss: 0.024357
# Epoch: 892 Train loss: 0.029865 Validation loss: 0.024302
# Epoch: 893 Train loss: 0.029881 Validation loss: 0.024246
# Epoch: 894 Train loss: 0.029896 Validation loss: 0.02419
# Epoch: 895 Train loss: 0.029911 Validation loss: 0.024134
# Epoch: 896 Train loss: 0.029926 Validation loss: 0.024079
# Epoch: 897 Train loss: 0.029941 Validation loss: 0.024023
# Epoch: 898 Train loss: 0.029957 Validation loss: 0.023967
# Epoch: 899 Train loss: 0.029972 Validation loss: 0.023911
# Epoch: 900 Train loss: 0.029987 Validation loss: 0.023855
# Epoch: 901 Train loss: 0.030003 Validation loss: 0.023799
# Epoch: 902 Train loss: 0.030018 Validation loss: 0.023742
# Epoch: 903 Train loss: 0.030033 Validation loss: 0.023686
# Epoch: 904 Train loss: 0.030049 Validation loss: 0.02363
# Epoch: 905 Train loss: 0.030064 Validation loss: 0.023574
# Epoch: 906 Train loss: 0.03008 Validation loss: 0.023518
# Epoch: 907 Train loss: 0.030095 Validation loss: 0.023462
# Epoch: 908 Train loss: 0.030111 Validation loss: 0.023405
# Epoch: 909 Train loss: 0.030126 Validation loss: 0.023349
# Epoch: 910 Train loss: 0.030142 Validation loss: 0.023293
# Epoch: 911 Train loss: 0.030157 Validation loss: 0.023237
# Epoch: 912 Train loss: 0.030173 Validation loss: 0.023181
# Epoch: 913 Train loss: 0.030188 Validation loss: 0.023124
# Epoch: 914 Train loss: 0.030204 Validation loss: 0.023068
# Epoch: 915 Train loss: 0.03022 Validation loss: 0.023012
# Epoch: 916 Train loss: 0.030235 Validation loss: 0.022956
# Epoch: 917 Train loss: 0.030251 Validation loss: 0.0229
# Epoch: 918 Train loss: 0.030267 Validation loss: 0.022844
# Epoch: 919 Train loss: 0.030283 Validation loss: 0.022788
# Epoch: 920 Train loss: 0.030298 Validation loss: 0.022732
# Epoch: 921 Train loss: 0.030314 Validation loss: 0.022676
# Epoch: 922 Train loss: 0.03033 Validation loss: 0.02262
# Epoch: 923 Train loss: 0.030346 Validation loss: 0.022565
# Epoch: 924 Train loss: 0.030362 Validation loss: 0.022509
# Epoch: 925 Train loss: 0.030378 Validation loss: 0.022453
# Epoch: 926 Train loss: 0.030394 Validation loss: 0.022398
# Epoch: 927 Train loss: 0.03041 Validation loss: 0.022342
# Epoch: 928 Train loss: 0.030426 Validation loss: 0.022287
# Epoch: 929 Train loss: 0.030442 Validation loss: 0.022231
# Epoch: 930 Train loss: 0.030458 Validation loss: 0.022176
# Epoch: 931 Train loss: 0.030474 Validation loss: 0.022121
# Epoch: 932 Train loss: 0.03049 Validation loss: 0.022065
# Epoch: 933 Train loss: 0.030506 Validation loss: 0.02201
# Epoch: 934 Train loss: 0.030522 Validation loss: 0.021955
# Epoch: 935 Train loss: 0.030539 Validation loss: 0.0219
# Epoch: 936 Train loss: 0.030555 Validation loss: 0.021846
# Epoch: 937 Train loss: 0.030571 Validation loss: 0.021791
# Epoch: 938 Train loss: 0.030587 Validation loss: 0.021736
# Epoch: 939 Train loss: 0.030604 Validation loss: 0.021681
# Epoch: 940 Train loss: 0.03062 Validation loss: 0.021627
# Epoch: 941 Train loss: 0.030636 Validation loss: 0.021573
# Epoch: 942 Train loss: 0.030653 Validation loss: 0.021518
# Epoch: 943 Train loss: 0.030669 Validation loss: 0.021464
# Epoch: 944 Train loss: 0.030686 Validation loss: 0.02141
# Epoch: 945 Train loss: 0.030702 Validation loss: 0.021356
# Epoch: 946 Train loss: 0.030719 Validation loss: 0.021303
# Epoch: 947 Train loss: 0.030735 Validation loss: 0.021249
# Epoch: 948 Train loss: 0.030752 Validation loss: 0.021195
# Epoch: 949 Train loss: 0.030768 Validation loss: 0.021142
# Epoch: 950 Train loss: 0.030785 Validation loss: 0.021088
# Epoch: 951 Train loss: 0.030802 Validation loss: 0.021035
# Epoch: 952 Train loss: 0.030818 Validation loss: 0.020982
# Epoch: 953 Train loss: 0.030835 Validation loss: 0.020929
# Epoch: 954 Train loss: 0.030852 Validation loss: 0.020876
# Epoch: 955 Train loss: 0.030868 Validation loss: 0.020824
# Epoch: 956 Train loss: 0.030885 Validation loss: 0.020771
# Epoch: 957 Train loss: 0.030902 Validation loss: 0.020719
# Epoch: 958 Train loss: 0.030919 Validation loss: 0.020666
# Epoch: 959 Train loss: 0.030936 Validation loss: 0.020614
# Epoch: 960 Train loss: 0.030953 Validation loss: 0.020562
# Epoch: 961 Train loss: 0.03097 Validation loss: 0.02051
# Epoch: 962 Train loss: 0.030987 Validation loss: 0.020459
# Epoch: 963 Train loss: 0.031004 Validation loss: 0.020407
# Epoch: 964 Train loss: 0.031021 Validation loss: 0.020356
# Epoch: 965 Train loss: 0.031038 Validation loss: 0.020304
# Epoch: 966 Train loss: 0.031055 Validation loss: 0.020253
# Epoch: 967 Train loss: 0.031072 Validation loss: 0.020202
# Epoch: 968 Train loss: 0.031089 Validation loss: 0.020151
# Epoch: 969 Train loss: 0.031106 Validation loss: 0.020101
# Epoch: 970 Train loss: 0.031123 Validation loss: 0.02005
# Epoch: 971 Train loss: 0.031141 Validation loss: 0.019999
# Epoch: 972 Train loss: 0.031158 Validation loss: 0.019949
# Epoch: 973 Train loss: 0.031175 Validation loss: 0.019899
# Epoch: 974 Train loss: 0.031192 Validation loss: 0.019849
# Epoch: 975 Train loss: 0.03121 Validation loss: 0.019799
# Epoch: 976 Train loss: 0.031227 Validation loss: 0.01975
# Epoch: 977 Train loss: 0.031244 Validation loss: 0.0197
# Epoch: 978 Train loss: 0.031262 Validation loss: 0.019651
# Epoch: 979 Train loss: 0.031279 Validation loss: 0.019602
# Epoch: 980 Train loss: 0.031297 Validation loss: 0.019553
# Epoch: 981 Train loss: 0.031314 Validation loss: 0.019504
# Epoch: 982 Train loss: 0.031331 Validation loss: 0.019455
# Epoch: 983 Train loss: 0.031349 Validation loss: 0.019407
# Epoch: 984 Train loss: 0.031367 Validation loss: 0.019358
# Epoch: 985 Train loss: 0.031384 Validation loss: 0.01931
# Epoch: 986 Train loss: 0.031402 Validation loss: 0.019262
# Epoch: 987 Train loss: 0.031419 Validation loss: 0.019214
# Epoch: 988 Train loss: 0.031437 Validation loss: 0.019167
# Epoch: 989 Train loss: 0.031454 Validation loss: 0.019119
# Epoch: 990 Train loss: 0.031472 Validation loss: 0.019071
# Epoch: 991 Train loss: 0.03149 Validation loss: 0.019024
# Epoch: 992 Train loss: 0.031507 Validation loss: 0.018977
# Epoch: 993 Train loss: 0.031525 Validation loss: 0.01893
# Epoch: 994 Train loss: 0.031543 Validation loss: 0.018883
# Epoch: 995 Train loss: 0.031561 Validation loss: 0.018837
# Epoch: 996 Train loss: 0.031578 Validation loss: 0.018791
# Epoch: 997 Train loss: 0.031596 Validation loss: 0.018744
# Epoch: 998 Train loss: 0.031614 Validation loss: 0.018698
# Epoch: 999 Train loss: 0.031632 Validation loss: 0.018652

# %% [markdown]
# During the training of the regularized model we can already notice, that, although there is still a difference between training and validation loss, the validation loss decreases as the training loss dreases. The effect of the regularization becomes even more evident if we plot the predictions of the regularized model and the overfitting model.

# %%
y_pred = big_reg_mdl(x)
y_pred_overfit = big_mdl(x)
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.plot(x, y_pred_overfit.numpy())
plt.legend(["Target", "Regularization", "No regularization", "Training samples"])
plt.show()

# %% [markdown]
# The model with regularization seems to follow the overall trend of the data, while the model without any regularization very precisely fits the training samples. This is espacilly evident in the interval $\left[0,0.5\right]$, where the prediction of the unregularized model shows an oscillating behavior. Such oscillations are however not present in the ground truth and therefore undesirable. The regularized model on the other hand is not as flexible as the unregularized model and therefore does not fit the target function well in the interval $\left[2.25, 3.0\right]$.
#
# ## Conclusion
# In this exercise we revisited the mathematical background for a simple regression task and covered it's practical implementation in Tensorflow 2. We also explored the phenomenon of overfitting and derived different regularizations from a probabilistic perspective. This exercise covers a very simple task with a very basic neural architecture and is intended as a primer for the second part of the regression exercise, which is dealing with a bigger and more realistic problem. In this second part we will consider the problem of regressing the age of a person from a potrait picture.
